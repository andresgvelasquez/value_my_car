# %% [markdown]
# # <a id='toc1_'></a>[Rusty Bargain ¿Cuánto vale mi carro?](#toc0_)

# %% [markdown]
# **Tabla de Contenido**<a id='toc0_'></a>
# - [Rusty Bargain ¿Cuánto vale mi carro?](#toc1_)
#   - [Descripción del proyecto](#toc1_1_)
#   - [Descripción de los datos](#toc1_2_)
#   - [Preparación de datos](#toc1_3_)
#     - [Imporación de librerías](#toc1_3_1_)
#     - [Carga de datos](#toc1_3_2_)
#     - [EDA](#toc1_3_3_)
#     - [Selección de columnas](#toc1_3_4_)
#     - [Formato a las columnas](#toc1_3_5_)
#     - [Duplicados explicitos](#toc1_3_6_)
#     - [Acotamiento de datos](#toc1_3_7_)
#     - [Valores ausentes](#toc1_3_8_)
#     - [Columnas con tipo de dato correcto](#toc1_3_9_)
#     - [Correlaciones](#toc1_3_10_)
#     - [Dividir el dataset en trenamiento y validación](#toc1_3_11_)
#     - [Escalado de datos](#toc1_3_12_)
#   - [Entrenamiento del modelo](#toc1_4_)
#     - [Modelo de regresión lineal](#toc1_4_1_)
#     - [Modelo de bosque aleatorio basico](#toc1_4_2_)
#     - [Catboost](#toc1_4_3_)
#     - [XGBoost](#toc1_4_4_)
#   - [Análisis del modelo](#toc1_5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Descripción del proyecto](#toc0_)
# El servicio de venta de autos usados Rusty Bargain está desarrollando una aplicación para atraer nuevos clientes. Gracias a esa app, puedes averiguar rápidamente el valor de mercado de tu coche. Tienes acceso al historial: especificaciones técnicas, versiones de equipamiento y precios. Tienes que crear un modelo que determine el valor de mercado.
# A Rusty Bargain le interesa:
# - La calidad de la predicción.
# - La velocidad de la predicción.
# - El tiempo requerido para el entrenamiento.

# %% [markdown]
# ## <a id='toc1_2_'></a>[Descripción de los datos](#toc0_)
# El dataset está almacenado en el archivo `../datasets/car_data.csv`.
# Características:
# - DateCrawled — fecha en la que se descargó el perfil de la base de datos
# - VehicleType — tipo de carrocería del vehículo
# - RegistrationYear — año de matriculación del vehículo
# - Gearbox — tipo de caja de cambios
# - Power — potencia (CV)
# - Model — modelo del vehículo
# - Mileage — kilometraje (medido en km de acuerdo con las especificidades regionales del conjunto de datos)
# - RegistrationMonth — mes de matriculación del vehículo
# - FuelType — tipo de combustible
# - Brand — marca del vehículo
# - NotRepaired — vehículo con o sin reparación
# - DateCreated — fecha de creación del perfil
# - NumberOfPictures — número de fotos del vehículo
# - PostalCode — código postal del propietario del perfil (usuario)
# - LastSeen — fecha de la última vez que el usuario estuvo activo
#
# Objetivo:
# - Price — precio (en euros)

# %% [markdown]
# ## <a id='toc1_3_'></a>[Preparación de datos](#toc0_)

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[Imporación de librerías](#toc0_)

# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
import xgboost as xgb
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### <a id='toc1_3_2_'></a>[Carga de datos](#toc0_)

# %%
# Carga de datos
car_data = pd.read_csv('../datasets/car_data.csv', parse_dates=['DateCrawled','DateCreated','LastSeen'])

# %% [markdown]
# ### <a id='toc1_3_3_'></a>[EDA](#toc0_)

# %%
# Mostrar 10 filas al azar
car_data.sample(10)
# Out:
#                DateCrawled  Price  VehicleType  RegistrationYear Gearbox  \
# 233012 2016-01-04 05:36:00   2300        sedan              2003  manual
# 326525 2016-08-03 16:06:00    350        small              1998  manual
# 278161 2016-04-04 09:55:00   3850  convertible              1997  manual
# 304405 2016-12-03 14:06:00    550        small              2001  manual
# 139459 2016-11-03 12:46:00    999        sedan              1999  manual
# 143528 2016-09-03 10:37:00   7800        wagon              2006    auto
# 173194 2016-03-29 23:56:00   9125        sedan              2006    auto
# 168639 2016-03-13 14:47:00    650        small              1997  manual
# 146562 2016-03-23 14:50:00    750        small              2001  manual
# 9167   2016-03-16 20:43:00   1900        wagon              2002  manual
#
#         Power     Model  Mileage  RegistrationMonth  FuelType          Brand  \
# 233012    125   carisma   125000                  5    petrol     mitsubishi
# 326525     54     corsa   150000                  4    petrol           opel
# 278161      0   z_reihe   150000                  3    petrol            bmw
# 304405     75     corsa   150000                  7    petrol           opel
# 139459     90  a_klasse   150000                 11  gasoline  mercedes_benz
# 143528    163       3er   150000                 11  gasoline            bmw
# 173194    272     other   125000                  6    petrol  mercedes_benz
# 168639     50      polo   150000                  3    petrol     volkswagen
# 146562     84     punto   150000                 10    petrol           fiat
# 9167        0     focus   125000                  4    petrol           ford
#
#        NotRepaired DateCreated  NumberOfPictures  PostalCode  \
# 233012          no  2016-01-04                 0       80809
# 326525          no  2016-08-03                 0       56412
# 278161          no  2016-04-04                 0       40235
# 304405         yes  2016-12-03                 0       56332
# 139459         yes  2016-11-03                 0       75015
# 143528          no  2016-09-03                 0       13507
# 173194          no  2016-03-29                 0       14715
# 168639         NaN  2016-03-13                 0       14532
# 146562          no  2016-03-23                 0       85406
# 9167            no  2016-03-16                 0        4357
#
#                   LastSeen
# 233012 2016-05-04 03:17:00
# 326525 2016-11-03 12:16:00
# 278161 2016-06-04 11:17:00
# 304405 2016-03-17 13:45:00
# 139459 2016-07-04 06:17:00
# 143528 2016-03-15 08:44:00
# 173194 2016-06-04 21:18:00
# 168639 2016-06-04 16:17:00
# 146562 2016-03-27 19:44:00
# 9167   2016-03-23 08:17:00

# %%
# Verificar valores ausentes, tipos de datos, número de observaciones
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  datetime64[ns]
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  datetime64[ns]
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 43.3+ MB

# %%
# Estadística descriptiva
car_data.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# **Nota:**
# - Cambiar el formato del nombre de las columnas (minúsculas y snake case).
# - Las columnas DateCrawled, DateCreated y LastSeen son fechas que no se relacionan con el precio, pueden ser eliminadas.
# - Las columna NumberOfPictures tiene un mínimo y máximo de 0, puede ser eliminada.

# %% [markdown]
# **Nota 2:**
#
# Debido a que se tienen 354 mil datos, se ha tomado la desición de discriminar la información con valores dudosos.
#
# - Price tiene valores de 0 a 20000. Se acotara el precio a un mínimo de 100.
# - RegistrationYear tiene valores de 0 a 9999. Se acotara el año de 1900 a 2024.
# - RegistrationMonth tiene valores de 0 a 12. Deberian ser unicamente 12 meses, se eliminaran los valores con el mes 0.

# %% [markdown]
# ### <a id='toc1_3_4_'></a>[Selección de columnas](#toc0_)

# %%
# Eliminar columnas irrelevantes
car_data_cln = car_data.drop(['NumberOfPictures', 'DateCrawled', 'DateCreated', 'LastSeen'], axis=1)

# %% [markdown]
# ### <a id='toc1_3_5_'></a>[Formato a las columnas](#toc0_)

# %%
# Dar formato al nombres de las columnas: minúsculas y snake_case
car_data_cln.columns = ['price', 'vehicle_type', 'registration_year', 'gearbox',
                        'power', 'model', 'mileage', 'registration_month', 'fuel_type', 'brand',
                        'not_repaired', 'postal_code']

# %% [markdown]
# ### <a id='toc1_3_6_'></a>[Duplicados explicitos](#toc0_)

# %%
# Verificar filas totalmente duplicadas
car_data_cln[car_data_cln.duplicated()]
# Out:
#         price vehicle_type  registration_year gearbox  power      model  \
# 3551     1670        sedan               1999  manual     75       golf
# 3786     2999        sedan               2002  manual    101       golf
# 3907      500        small               1999  manual     55      corsa
# 4134    18750        sedan               2014  manual    150       golf
# 4222    14500        wagon               2007  manual    140         a6
# ...       ...          ...                ...     ...    ...        ...
# 354336   3299          NaN               2005    auto      0  outlander
# 354337  11500        sedan               2004    auto    445        7er
# 354352   6500        sedan               2003    auto    145   e_klasse
# 354355   4400        sedan               2008  manual    105       leon
# 354363   1150          bus               2000  manual      0     zafira
#
#         mileage  registration_month fuel_type          brand not_repaired  \
# 3551     150000                   8    petrol     volkswagen           no
# 3786     150000                   6  gasoline     volkswagen           no
# 3907     150000                  12    petrol           opel           no
# 4134      20000                   9  gasoline     volkswagen           no
# 4222     100000                   3  gasoline           audi           no
# ...         ...                 ...       ...            ...          ...
# 354336   150000                   4    petrol     mitsubishi          NaN
# 354337   125000                   0    petrol            bmw          NaN
# 354352   150000                   3  gasoline  mercedes_benz           no
# 354355   150000                   7  gasoline           seat           no
# 354363   150000                   3    petrol           opel           no
#
#         postal_code
# 3551          52388
# 3786          32756
# 3907          51377
# 4134          38518
# 4222          94060
# ...             ...
# 354336        17034
# 354337         4107
# 354352        60437
# 354355        45896
# 354363        26624
#
# [21333 rows x 12 columns]

# %%
# Verificar una observación al azar
car_data_cln[(car_data_cln['registration_year']==1999) & (car_data_cln['price']==1670)]
# Out:
#         price vehicle_type  registration_year gearbox  power   model  mileage  \
# 824      1670        sedan               1999  manual     75    golf   150000
# 3551     1670        sedan               1999  manual     75    golf   150000
# 163866   1670        small               1999  manual     58    clio    80000
# 232731   1670        sedan               1999  manual     75   astra   150000
# 308127   1670          bus               1999  manual    115  zafira   150000
# 352652   1670        sedan               1999  manual      0   astra   150000
#
#         registration_month fuel_type       brand not_repaired  postal_code
# 824                      8    petrol  volkswagen           no        52388
# 3551                     8    petrol  volkswagen           no        52388
# 163866                   2    petrol     renault           no        56412
# 232731                   8    petrol        opel           no        23701
# 308127                   4    petrol        opel           no        71634
# 352652                   5    petrol        opel          NaN        24109

# %% [markdown]
# **Nota:**
# Existen 21333 filas duplicadas. Contienen postal_code, el mismo mes, el mismo millaje... es demasiada coincidencia, vamos a eliminarlas.

# %%
# Eliminar filas totalmente duplicadas
car_data_cln.drop_duplicates(inplace=True)

# %% [markdown]
# ### <a id='toc1_3_7_'></a>[Acotamiento de datos](#toc0_)

# %%
# Acotar los datos de las columnas regitration_year, power, price, registration_month
# Debido a datos que son dudosos

filtro_reg_year = (
    (car_data_cln['registration_year'] > 1900)
    & (car_data_cln['registration_year'] < 2024)
)

filtro_power = (
    (car_data_cln['power']>0)
)

filtro_price = (
    (car_data_cln['price'] > 100)
)

filtro_reg_month = (
    (car_data_cln['registration_month'] > 0)
)

car_data_cln = car_data_cln[filtro_reg_year & filtro_power & filtro_price & filtro_reg_month]
car_data_cln
# Out:
#         price vehicle_type  registration_year gearbox  power        model  \
# 1       18300        coupe               2011  manual    190          NaN
# 2        9800          suv               2004    auto    163        grand
# 3        1500        small               2001  manual     75         golf
# 4        3600        small               2008  manual     69        fabia
# 5         650        sedan               1995  manual    102          3er
# ...       ...          ...                ...     ...    ...          ...
# 354361   5250          NaN               2016    auto    150          159
# 354362   3200        sedan               2004  manual    225         leon
# 354366   1199  convertible               2000    auto    101       fortwo
# 354367   9200          bus               1996  manual    102  transporter
# 354368   3400        wagon               2002  manual    100         golf
#
#         mileage  registration_month fuel_type       brand not_repaired  \
# 1        125000                   5  gasoline        audi          yes
# 2        125000                   8  gasoline        jeep          NaN
# 3        150000                   6    petrol  volkswagen           no
# 4         90000                   7  gasoline       skoda           no
# 5        150000                  10    petrol         bmw          yes
# ...         ...                 ...       ...         ...          ...
# 354361   150000                  12       NaN  alfa_romeo           no
# 354362   150000                   5    petrol        seat          yes
# 354366   125000                   3    petrol       smart           no
# 354367   150000                   3  gasoline  volkswagen           no
# 354368   150000                   6  gasoline  volkswagen          NaN
#
#         postal_code
# 1             66954
# 2             90480
# 3             91074
# 4             60437
# 5             33775
# ...             ...
# 354361        51371
# 354362        96465
# 354366        26135
# 354367        87439
# 354368        40764
#
# [267312 rows x 12 columns]

# %% [markdown]
# **Nota:**
# Debido a que aun contamos con una gran cantidad de datos (267mil), se eliminaran aquellos con valores ausentes.

# %% [markdown]
# ### <a id='toc1_3_8_'></a>[Valores ausentes](#toc0_)

# %%
# Eliminar valores ausentes 
car_data_cln.dropna(inplace=True)
car_data_cln
# Out:
#         price vehicle_type  registration_year gearbox  power        model  \
# 3        1500        small               2001  manual     75         golf
# 4        3600        small               2008  manual     69        fabia
# 5         650        sedan               1995  manual    102          3er
# 6        2200  convertible               2004  manual    109      2_reihe
# 10       2000        sedan               2004  manual    105      3_reihe
# ...       ...          ...                ...     ...    ...          ...
# 354359   7900        sedan               2010  manual    140         golf
# 354360   3999        wagon               2005  manual      3          3er
# 354362   3200        sedan               2004  manual    225         leon
# 354366   1199  convertible               2000    auto    101       fortwo
# 354367   9200          bus               1996  manual    102  transporter
#
#         mileage  registration_month fuel_type       brand not_repaired  \
# 3        150000                   6    petrol  volkswagen           no
# 4         90000                   7  gasoline       skoda           no
# 5        150000                  10    petrol         bmw          yes
# 6        150000                   8    petrol     peugeot           no
# 10       150000                  12    petrol       mazda           no
# ...         ...                 ...       ...         ...          ...
# 354359   150000                   7  gasoline  volkswagen           no
# 354360   150000                   5  gasoline         bmw           no
# 354362   150000                   5    petrol        seat          yes
# 354366   125000                   3    petrol       smart           no
# 354367   150000                   3  gasoline  volkswagen           no
#
#         postal_code
# 3             91074
# 4             60437
# 5             33775
# 6             67112
# 10            96224
# ...             ...
# 354359        75223
# 354360        81825
# 354362        96465
# 354366        26135
# 354367        87439
#
# [210816 rows x 12 columns]

# %% [markdown]
# ### <a id='toc1_3_9_'></a>[Columnas con tipo de dato correcto](#toc0_)

# %%
# Ver los valores del tipo de vehículos
car_data_cln.vehicle_type.value_counts()
# Out:
# sedan          62597
# small          49146
# wagon          43977
# bus            20719
# convertible    14253
# coupe          10501
# suv             8298
# other           1325
# Name: vehicle_type, dtype: int64

# %%
# Ver los valores de la caja de cambios
car_data_cln.gearbox.value_counts()
# Out:
# manual    166731
# auto       44085
# Name: gearbox, dtype: int64

# %%
# Ver los modelos
car_data_cln.model.value_counts()
# Out:
# golf                  17542
# other                 15911
# 3er                   12819
# polo                   7375
# corsa                  6758
#                       ...
# serie_3                   3
# elefantino                3
# samara                    2
# range_rover_evoque        1
# rangerover                1
# Name: model, Length: 249, dtype: int64

# %%
# Ver los tipos de combustible
car_data_cln.fuel_type.value_counts()
# Out:
# petrol      138061
# gasoline     68806
# lpg           3302
# cng            393
# hybrid         161
# other           47
# electric        46
# Name: fuel_type, dtype: int64

# %%
# Ver las marcas
car_data_cln.brand.value_counts().sort_index()
# Out:
# alfa_romeo        1457
# audi             18869
# bmw              23638
# chevrolet         1097
# chrysler           863
# citroen           3195
# dacia              635
# daewoo             277
# daihatsu           425
# fiat              5312
# ford             14336
# honda             1706
# hyundai           2408
# jaguar             345
# jeep               446
# kia               1608
# lada               116
# lancia             260
# land_rover         366
# mazda             3437
# mercedes_benz    20799
# mini              2433
# mitsubishi        1759
# nissan            2960
# opel             21767
# peugeot           6665
# porsche            489
# renault           9559
# rover              221
# saab               361
# seat              4254
# skoda             3913
# smart             2935
# subaru             458
# suzuki            1458
# toyota            3232
# trabant            137
# volkswagen       44495
# volvo             2125
# Name: brand, dtype: int64

# %%
# Ver los valores de reparación
car_data_cln.not_repaired.value_counts()
# Out:
# no     189433
# yes     21383
# Name: not_repaired, dtype: int64

# %% [markdown]
# **Notas:**
# - VehicleType, Gearbox, FuelType, de object a category.
# - NotRepaired de objetct a bool.

# %%
# Cambiar los tipos de datos de vehicle_type, fuel_type y gearbox
car_data_cln['vehicle_type'] = car_data_cln['vehicle_type'].astype('category')
car_data_cln['fuel_type'] = car_data_cln['fuel_type'].astype('category')
car_data_cln['gearbox'] = car_data_cln['gearbox'].astype('category')

# Convertir NotRepaired a bool
mapeo = {'yes': True, 'no': False}
car_data_cln['not_repaired'] = car_data_cln['not_repaired'].map(mapeo)

car_data_cln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210816 entries, 3 to 354367
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   price               210816 non-null  int64
#  1   vehicle_type        210816 non-null  category
#  2   registration_year   210816 non-null  int64
#  3   gearbox             210816 non-null  category
#  4   power               210816 non-null  int64
#  5   model               210816 non-null  object
#  6   mileage             210816 non-null  int64
#  7   registration_month  210816 non-null  int64
#  8   fuel_type           210816 non-null  category
#  9   brand               210816 non-null  object
#  10  not_repaired        210816 non-null  bool
#  11  postal_code         210816 non-null  int64
# dtypes: bool(1), category(3), int64(6), object(2)
# memory usage: 15.3+ MB

# %% [markdown]
# ### <a id='toc1_3_10_'></a>[Correlaciones](#toc0_)

# %%
# Correlaciones de valores númericos
car_data_cln.corr()
# Out:
#                        price  registration_year     power   mileage  \
# price               1.000000           0.556764  0.193507 -0.405617
# registration_year   0.556764           1.000000  0.054869 -0.371042
# power               0.193507           0.054869  1.000000  0.047089
# mileage            -0.405617          -0.371042  0.047089  1.000000
# registration_month  0.008747          -0.003397  0.006609  0.007451
# not_repaired       -0.207749          -0.116393 -0.015003  0.087378
# postal_code         0.063686           0.034595  0.015637 -0.015794
#
#                     registration_month  not_repaired  postal_code
# price                         0.008747     -0.207749     0.063686
# registration_year            -0.003397     -0.116393     0.034595
# power                         0.006609     -0.015003     0.015637
# mileage                       0.007451      0.087378    -0.015794
# registration_month            1.000000     -0.010660    -0.004568
# not_repaired                 -0.010660      1.000000    -0.003140
# postal_code                  -0.004568     -0.003140     1.000000

# %% [markdown]
# **Notas:**
# - La características númerica que mas afectan el precio del carro son: registration_year (corr = 0.55) y mileage (-0.40). Cuanto mas reciente sea el año de registro mayor sera el precio y cuanto mas alto sea el millaje menor sera el precio.
# - Milege y not_repaired, son las unicas columnas que afectan negativamente.
# - La característica númerica que menos afecta positivamente es el mes de registro (corr = 0.008), debido a su baja relación con el precio y las otras varibles, sera descartada. Ademas no aporta un valor adicional al modelo.
# - Se convertira la columna registration_year a los años de antiguedad (año actual - año de registro)

# %%
# Eliminar la columna registration_month
car_data_cln.drop('registration_month', axis=1, inplace=True)

# %%
# Obtener la antiguedad del auto a partir de la columna de registration_year
# La correlacion pasara de ser positiva a negativa.
año_actual = 2024
car_data_cln['registration_year'] = año_actual - car_data_cln['registration_year'] 
car_data_cln.rename(columns={'registration_year':'years_since_registration'})
car_data_cln
# Out:
#         price vehicle_type  registration_year gearbox  power        model  \
# 3        1500        small                 23  manual     75         golf
# 4        3600        small                 16  manual     69        fabia
# 5         650        sedan                 29  manual    102          3er
# 6        2200  convertible                 20  manual    109      2_reihe
# 10       2000        sedan                 20  manual    105      3_reihe
# ...       ...          ...                ...     ...    ...          ...
# 354359   7900        sedan                 14  manual    140         golf
# 354360   3999        wagon                 19  manual      3          3er
# 354362   3200        sedan                 20  manual    225         leon
# 354366   1199  convertible                 24    auto    101       fortwo
# 354367   9200          bus                 28  manual    102  transporter
#
#         mileage fuel_type       brand  not_repaired  postal_code
# 3        150000    petrol  volkswagen         False        91074
# 4         90000  gasoline       skoda         False        60437
# 5        150000    petrol         bmw          True        33775
# 6        150000    petrol     peugeot         False        67112
# 10       150000    petrol       mazda         False        96224
# ...         ...       ...         ...           ...          ...
# 354359   150000  gasoline  volkswagen         False        75223
# 354360   150000  gasoline         bmw         False        81825
# 354362   150000    petrol        seat          True        96465
# 354366   125000    petrol       smart         False        26135
# 354367   150000  gasoline  volkswagen         False        87439
#
# [210816 rows x 11 columns]

# %%
# Porcentaje de valores ausentes por columna
car_data_cln.isna().sum()*100/len(car_data_cln)
# Out:
# price                0.0
# vehicle_type         0.0
# registration_year    0.0
# gearbox              0.0
# power                0.0
# model                0.0
# mileage              0.0
# fuel_type            0.0
# brand                0.0
# not_repaired         0.0
# postal_code          0.0
# dtype: float64

# %% [markdown]
# ### <a id='toc1_3_11_'></a>[Dividir el dataset en trenamiento y validación](#toc0_)

# %%
# Dividir las características del objetivo
features = car_data_cln.drop('price', axis=1)
target = car_data_cln.price

# Dividir el dataset en un conjunto de entrenamiento y validación
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.3, random_state=54321
)

# %% [markdown]
# ### <a id='toc1_3_12_'></a>[Escalado de datos](#toc0_)

# %%
def featureScaler(df, numeric_cols, categ_cols):
    ''' 
    Convierte un dataframe con características númericas
    en un dataframe estandarizado.
    in: dataframe
    out: dataframe estándar para las columnas númericas + categoricas
    '''
    df = df.reset_index(drop=True)
    scaler = StandardScaler()                                                   
    features_scaled = scaler.fit_transform(df[numeric_cols])                            
    df_features_scaled = pd.DataFrame(features_scaled, columns=numeric_cols)   
    df_scaled = pd.concat([df_features_scaled,df[categ_cols]], axis=1)
    return df_scaled

# %%
# Definir las columnas numericas y categoricas
feat_num_cols = ['registration_year', 'power', 'mileage', 'postal_code']
feat_categ_cols = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']

# Escalar el conjunto de prueba y entrenamiento 
features_train_scaled = featureScaler(features_train, feat_num_cols, feat_categ_cols)
features_test_scaled = featureScaler(features_test, feat_num_cols, feat_categ_cols)

# Resetear el indice de los objetivos
target_train = target_train.reset_index(drop=True)
target_test = target_test.reset_index(drop=True)

# %%
# Crear un dataset con las columnas categoricas en one hot encoding
features_train_scaled_ohe = pd.get_dummies(features_train_scaled, columns=feat_categ_cols, drop_first=True)
features_test_scaled_ohe = pd.get_dummies(features_test_scaled, columns=feat_categ_cols, drop_first=True)

# Crear columnas faltantes en el conjuto de prueba
for col in features_train_scaled_ohe.columns:
    if ~(col in features_test_scaled_ohe):
        features_test_scaled_ohe[col] = 0

# Reordenar las columnas nuevas
features_test_scaled_ohe = features_test_scaled_ohe[features_train_scaled_ohe.columns]

# %% [markdown]
# ## <a id='toc1_4_'></a>[Entrenamiento del modelo](#toc0_)

# %% [markdown]
# ### <a id='toc1_4_1_'></a>[Modelo de regresión lineal](#toc0_)

# %%
class SGDLinearRegression:
    def __init__(self, step_size=0.001, epochs=100, batch_size=100, reg_weight=10.0):
        self.step_size = step_size
        self.epochs = epochs
        self.batch_size = batch_size
        self.reg_weight = reg_weight

    def fit(self, train_features, train_target):
        X = np.concatenate(
            (np.ones((train_features.shape[0], 1)), train_features), axis=1
        )
        y = train_target
        w = np.zeros(X.shape[1])

        for _ in range(self.epochs):
            batches_count = X.shape[0] // self.batch_size
            for i in range(batches_count):
                begin = i * self.batch_size
                end = (i + 1) * self.batch_size
                X_batch = X[begin:end, :]
                y_batch = y[begin:end]

                gradient = (
                    2
                    * X_batch.T.dot(X_batch.dot(w) - y_batch)
                    / X_batch.shape[0]
                )

                reg = 2 * w.copy()
                reg[0] = 0 
                gradient += self.reg_weight * reg 
                
                w -= self.step_size * gradient

        self.w = w[1:]
        self.w0 = w[0]

    def predict(self, test_features):
        return test_features.dot(self.w) + self.w0

# %%
# Medir el tiempo 

# Los mejores hiperparámetros encontrados par el modelo de regresión lineal
# Se utilizara como prueba de cordura
model = SGDLinearRegression(0.01, 10, 100, 1.0)

# Convertir los valores 
# %time model.fit(features_train_scaled_ohe.astype(float), target_train)
pred_train = model.predict(features_train_scaled_ohe.astype(float))
pred_test = model.predict(features_test_scaled_ohe.astype(float))
rmse_train = mean_squared_error(target_train, pred_train) ** 0.5
rmse_test = mean_squared_error(target_test, pred_test) ** 0.5
print(f'RMSE Train: {rmse_train}')
print(f'RMSE Test: {rmse_test}')
# Out:
# CPU times: user 12.2 s, sys: 21.3 s, total: 33.5 s
# Wall time: 33.5 s
# RMSE Train: 3703.074237852838
# RMSE Test: 4753.702665356179

# %% [markdown]
# ### <a id='toc1_4_2_'></a>[Modelo de bosque aleatorio basico](#toc0_)

# %%
# Ya se incluyen los mejores hiperaparametros
gb_model = GradientBoostingRegressor(
    learning_rate=0.0045, max_depth=23, min_samples_leaf=7, min_samples_split=2, n_estimators=5, random_state=54321
)
# %time gb_model.fit(features_train_scaled_ohe.astype(float), target_train)
predicts = gb_model.predict(features_test_scaled_ohe.astype(float))
mse = mean_squared_error(target_test, predicts) ** 0.5
print(f'Mean Squared Error en conjunto de prueba: {mse}')
# Out:
# CPU times: user 20.7 s, sys: 167 ms, total: 20.9 s
# Wall time: 20.9 s
# Mean Squared Error en conjunto de prueba: 4730.943342117087

# %% [markdown]
# **Nota:** No hubo una mejora significativa en el error, solo hay una diferencia de 23 USD de error con respecto al modelo de regresión lineal. En cuestión del tiempo hubo una reducción del 39.22%.

# %% [markdown]
# ### <a id='toc1_4_3_'></a>[Catboost](#toc0_)

# %%
model = CatBoostRegressor(iterations=1000, depth=10, learning_rate=0.1, loss_function='RMSE')
# %time model.fit(features_train, target_train, cat_features=feat_categ_cols)
predicts = model.predict(features_test)
rmse = mean_squared_error(target_test, predicts) ** 0.5
print(f'RMSE: {rmse}')
# Out:
# 0:	learn: 4390.3871574	total: 615ms	remaining: 10m 14s
# 1:	learn: 4074.2645037	total: 1.17s	remaining: 9m 41s
# 2:	learn: 3794.3828704	total: 1.69s	remaining: 9m 22s
# 3:	learn: 3548.4626571	total: 2.24s	remaining: 9m 18s
# 4:	learn: 3328.6763183	total: 2.7s	remaining: 8m 58s
# 5:	learn: 3138.4907059	total: 3.2s	remaining: 8m 50s
# 6:	learn: 2972.7036806	total: 3.69s	remaining: 8m 43s
# 7:	learn: 2819.7947326	total: 4.18s	remaining: 8m 38s
# 8:	learn: 2683.8801755	total: 4.68s	remaining: 8m 35s
# 9:	learn: 2565.0726536	total: 5.18s	remaining: 8m 32s
# 10:	learn: 2465.5441394	total: 5.7s	remaining: 8m 32s
# 11:	learn: 2374.3299799	total: 6.16s	remaining: 8m 27s
# 12:	learn: 2299.3358678	total: 6.68s	remaining: 8m 27s
# 13:	learn: 2231.1783489	total: 7.09s	remaining: 8m 19s
# 14:	learn: 2173.4459022	total: 7.53s	remaining: 8m 14s
# 15:	learn: 2121.8912067	total: 8.06s	remaining: 8m 15s
# 16:	learn: 2077.7091089	total: 8.58s	remaining: 8m 16s
# 17:	learn: 2039.9099637	total: 9.01s	remaining: 8m 11s
# 18:	learn: 2003.3702756	total: 9.51s	remaining: 8m 11s
# 19:	learn: 1970.5553926	total: 9.98s	remaining: 8m 8s
# 20:	learn: 1939.8391333	total: 10.5s	remaining: 8m 7s
# 21:	learn: 1915.3732302	total: 10.9s	remaining: 8m 5s
# 22:	learn: 1893.7609925	total: 11.4s	remaining: 8m 5s
# 23:	learn: 1871.3688925	total: 11.9s	remaining: 8m 5s
# 24:	learn: 1855.0556532	total: 12.4s	remaining: 8m 5s
# 25:	learn: 1837.4875312	total: 13s	remaining: 8m 6s
# 26:	learn: 1823.0240443	total: 13.5s	remaining: 8m 5s
# 27:	learn: 1811.5076961	total: 14s	remaining: 8m 4s
# 28:	learn: 1799.1639111	total: 14.5s	remaining: 8m 5s
# 29:	learn: 1787.8842234	total: 15.1s	remaining: 8m 7s
# 30:	learn: 1777.9765773	total: 15.6s	remaining: 8m 6s
# 31:	learn: 1769.6365877	total: 16.1s	remaining: 8m 5s
# 32:	learn: 1760.3063852	total: 16.5s	remaining: 8m 4s
# 33:	learn: 1749.3135028	total: 17s	remaining: 8m 2s
# 34:	learn: 1743.1217176	total: 17.4s	remaining: 8m
# 35:	learn: 1736.9058968	total: 17.9s	remaining: 7m 58s
# 36:	learn: 1731.9731340	total: 18.4s	remaining: 7m 57s
# 37:	learn: 1725.3850664	total: 18.8s	remaining: 7m 56s
# 38:	learn: 1721.1229821	total: 19.3s	remaining: 7m 55s
# 39:	learn: 1716.7399580	total: 19.8s	remaining: 7m 54s
# 40:	learn: 1711.1361815	total: 20.1s	remaining: 7m 50s
# 41:	learn: 1707.3748911	total: 20.5s	remaining: 7m 47s
# 42:	learn: 1701.2132496	total: 20.9s	remaining: 7m 45s
# 43:	learn: 1696.0926722	total: 21.4s	remaining: 7m 44s
# 44:	learn: 1692.4025077	total: 21.9s	remaining: 7m 44s
# 45:	learn: 1689.3787911	total: 22.3s	remaining: 7m 42s
# 46:	learn: 1685.3875974	total: 22.7s	remaining: 7m 40s
# 47:	learn: 1682.4286051	total: 23.1s	remaining: 7m 37s
# 48:	learn: 1679.1995388	total: 23.5s	remaining: 7m 36s
# 49:	learn: 1677.2793462	total: 24s	remaining: 7m 35s
# 50:	learn: 1674.1306448	total: 24.5s	remaining: 7m 35s
# 51:	learn: 1670.3557774	total: 24.9s	remaining: 7m 34s
# 52:	learn: 1667.8445978	total: 25.4s	remaining: 7m 34s
# 53:	learn: 1665.0144763	total: 25.9s	remaining: 7m 34s
# 54:	learn: 1661.3321017	total: 26.4s	remaining: 7m 32s
# 55:	learn: 1659.0986688	total: 26.9s	remaining: 7m 33s
# 56:	learn: 1655.8912588	total: 27.3s	remaining: 7m 31s
# 57:	learn: 1653.8038370	total: 27.8s	remaining: 7m 31s
# 58:	learn: 1651.2834548	total: 28.3s	remaining: 7m 30s
# 59:	learn: 1649.5472390	total: 28.8s	remaining: 7m 30s
# 60:	learn: 1647.5162201	total: 29.2s	remaining: 7m 29s
# 61:	learn: 1645.4669353	total: 29.6s	remaining: 7m 28s
# 62:	learn: 1643.6146891	total: 30.2s	remaining: 7m 28s
# 63:	learn: 1641.5004831	total: 30.6s	remaining: 7m 28s
# 64:	learn: 1640.5114353	total: 31.1s	remaining: 7m 27s
# 65:	learn: 1638.8299606	total: 31.7s	remaining: 7m 28s
# 66:	learn: 1636.6465344	total: 32.2s	remaining: 7m 28s
# 67:	learn: 1634.2244181	total: 32.7s	remaining: 7m 27s
# 68:	learn: 1632.8884109	total: 33.1s	remaining: 7m 27s
# 69:	learn: 1630.8714320	total: 33.6s	remaining: 7m 26s
# 70:	learn: 1628.3191281	total: 34.1s	remaining: 7m 26s
# 71:	learn: 1627.2165840	total: 34.6s	remaining: 7m 25s
# 72:	learn: 1625.4736489	total: 35s	remaining: 7m 24s
# 73:	learn: 1623.0450981	total: 35.6s	remaining: 7m 25s
# 74:	learn: 1621.2688395	total: 36.1s	remaining: 7m 25s
# 75:	learn: 1619.6201088	total: 36.5s	remaining: 7m 23s
# 76:	learn: 1617.2380496	total: 37s	remaining: 7m 23s
# 77:	learn: 1615.2233030	total: 37.5s	remaining: 7m 23s
# 78:	learn: 1613.6251392	total: 38s	remaining: 7m 23s
# 79:	learn: 1611.9323815	total: 38.5s	remaining: 7m 22s
# 80:	learn: 1609.7453529	total: 39s	remaining: 7m 21s
# 81:	learn: 1608.6558279	total: 39.4s	remaining: 7m 21s
# 82:	learn: 1606.6689476	total: 39.9s	remaining: 7m 20s
# 83:	learn: 1605.3769758	total: 40.3s	remaining: 7m 19s
# 84:	learn: 1604.4568071	total: 40.7s	remaining: 7m 18s
# 85:	learn: 1603.5883602	total: 41.3s	remaining: 7m 18s
# 86:	learn: 1602.2149556	total: 41.8s	remaining: 7m 18s
# 87:	learn: 1601.4361966	total: 42.2s	remaining: 7m 17s
# 88:	learn: 1598.6318271	total: 42.7s	remaining: 7m 17s
# 89:	learn: 1597.6861178	total: 43.2s	remaining: 7m 16s
# 90:	learn: 1596.6561632	total: 43.7s	remaining: 7m 16s
# 91:	learn: 1594.5555735	total: 44.2s	remaining: 7m 16s
# 92:	learn: 1593.3808776	total: 44.7s	remaining: 7m 15s
# 93:	learn: 1592.1054900	total: 45.1s	remaining: 7m 15s
# 94:	learn: 1591.2535992	total: 45.6s	remaining: 7m 14s
# 95:	learn: 1588.9637177	total: 46.1s	remaining: 7m 14s
# 96:	learn: 1587.5556885	total: 46.5s	remaining: 7m 13s
# 97:	learn: 1586.1598096	total: 47s	remaining: 7m 12s
# 98:	learn: 1585.5546674	total: 47.5s	remaining: 7m 12s
# 99:	learn: 1584.6081346	total: 48s	remaining: 7m 11s
# 100:	learn: 1583.2782526	total: 48.5s	remaining: 7m 12s
# 101:	learn: 1582.3606951	total: 49s	remaining: 7m 11s
# 102:	learn: 1580.4739071	total: 49.4s	remaining: 7m 10s
# 103:	learn: 1579.2065170	total: 49.9s	remaining: 7m 10s
# 104:	learn: 1578.7435521	total: 50.4s	remaining: 7m 9s
# 105:	learn: 1577.0365506	total: 50.9s	remaining: 7m 8s
# 106:	learn: 1575.5675004	total: 51.4s	remaining: 7m 8s
# 107:	learn: 1574.0947336	total: 51.9s	remaining: 7m 8s
# 108:	learn: 1572.7364371	total: 52.4s	remaining: 7m 8s
# 109:	learn: 1570.8383842	total: 52.9s	remaining: 7m 7s
# 110:	learn: 1568.9225254	total: 53.3s	remaining: 7m 7s
# 111:	learn: 1567.9521694	total: 53.8s	remaining: 7m 6s
# 112:	learn: 1566.6767258	total: 54.3s	remaining: 7m 6s
# 113:	learn: 1565.8085108	total: 54.7s	remaining: 7m 5s
# 114:	learn: 1565.2649596	total: 55.2s	remaining: 7m 5s
# 115:	learn: 1563.4190946	total: 55.7s	remaining: 7m 4s
# 116:	learn: 1562.7374340	total: 56.3s	remaining: 7m 4s
# 117:	learn: 1562.0888467	total: 56.9s	remaining: 7m 5s
# 118:	learn: 1561.4517221	total: 57.4s	remaining: 7m 4s
# 119:	learn: 1560.6494682	total: 57.9s	remaining: 7m 4s
# 120:	learn: 1559.5093272	total: 58.4s	remaining: 7m 4s
# 121:	learn: 1558.6581482	total: 58.9s	remaining: 7m 3s
# 122:	learn: 1557.2377755	total: 59.4s	remaining: 7m 3s
# 123:	learn: 1556.4587355	total: 59.9s	remaining: 7m 3s
# 124:	learn: 1555.2288815	total: 1m	remaining: 7m 3s
# 125:	learn: 1554.1859542	total: 1m	remaining: 7m 2s
# 126:	learn: 1553.4819423	total: 1m 1s	remaining: 7m 1s
# 127:	learn: 1552.6336525	total: 1m 1s	remaining: 7m 1s
# 128:	learn: 1552.0069381	total: 1m 2s	remaining: 7m
# 129:	learn: 1551.2885720	total: 1m 2s	remaining: 7m
# 130:	learn: 1549.4918073	total: 1m 3s	remaining: 7m
# 131:	learn: 1548.6733457	total: 1m 3s	remaining: 6m 59s
# 132:	learn: 1548.0128963	total: 1m 4s	remaining: 6m 59s
# 133:	learn: 1547.2121899	total: 1m 4s	remaining: 6m 58s
# 134:	learn: 1546.4987989	total: 1m 5s	remaining: 6m 57s
# 135:	learn: 1546.1188799	total: 1m 5s	remaining: 6m 57s
# 136:	learn: 1544.5649116	total: 1m 6s	remaining: 6m 56s
# 137:	learn: 1543.4135373	total: 1m 6s	remaining: 6m 56s
# 138:	learn: 1542.6434247	total: 1m 7s	remaining: 6m 55s
# 139:	learn: 1541.9414972	total: 1m 7s	remaining: 6m 55s
# 140:	learn: 1541.4222214	total: 1m 8s	remaining: 6m 55s
# 141:	learn: 1540.5101704	total: 1m 8s	remaining: 6m 54s
# 142:	learn: 1539.8643596	total: 1m 9s	remaining: 6m 54s
# 143:	learn: 1539.2498394	total: 1m 9s	remaining: 6m 53s
# 144:	learn: 1538.4412598	total: 1m 10s	remaining: 6m 53s
# 145:	learn: 1537.8086564	total: 1m 10s	remaining: 6m 52s
# 146:	learn: 1536.4596284	total: 1m 11s	remaining: 6m 52s
# 147:	learn: 1535.6283111	total: 1m 11s	remaining: 6m 51s
# 148:	learn: 1534.4409876	total: 1m 12s	remaining: 6m 51s
# 149:	learn: 1533.2356970	total: 1m 12s	remaining: 6m 51s
# 150:	learn: 1532.7107568	total: 1m 13s	remaining: 6m 50s
# 151:	learn: 1532.2453953	total: 1m 13s	remaining: 6m 50s
# 152:	learn: 1531.7635457	total: 1m 14s	remaining: 6m 49s
# 153:	learn: 1531.2646886	total: 1m 14s	remaining: 6m 49s
# 154:	learn: 1530.5912223	total: 1m 15s	remaining: 6m 49s
# 155:	learn: 1530.1195798	total: 1m 15s	remaining: 6m 49s
# 156:	learn: 1529.6534117	total: 1m 16s	remaining: 6m 48s
# 157:	learn: 1529.1645452	total: 1m 16s	remaining: 6m 47s
# 158:	learn: 1528.5177173	total: 1m 17s	remaining: 6m 47s
# 159:	learn: 1527.9684413	total: 1m 17s	remaining: 6m 47s
# 160:	learn: 1527.4034785	total: 1m 18s	remaining: 6m 46s
# 161:	learn: 1526.3678999	total: 1m 18s	remaining: 6m 46s
# 162:	learn: 1525.7637700	total: 1m 19s	remaining: 6m 46s
# 163:	learn: 1524.3312111	total: 1m 19s	remaining: 6m 45s
# 164:	learn: 1523.3024831	total: 1m 20s	remaining: 6m 45s
# 165:	learn: 1522.5501579	total: 1m 20s	remaining: 6m 44s
# 166:	learn: 1520.6664222	total: 1m 21s	remaining: 6m 44s
# 167:	learn: 1519.4523522	total: 1m 21s	remaining: 6m 44s
# 168:	learn: 1519.0656744	total: 1m 22s	remaining: 6m 44s
# 169:	learn: 1518.6014702	total: 1m 22s	remaining: 6m 43s
# 170:	learn: 1518.0876539	total: 1m 23s	remaining: 6m 42s
# 171:	learn: 1517.4435378	total: 1m 23s	remaining: 6m 42s
# 172:	learn: 1517.0736009	total: 1m 24s	remaining: 6m 41s
# 173:	learn: 1516.0075643	total: 1m 24s	remaining: 6m 42s
# 174:	learn: 1515.3461165	total: 1m 25s	remaining: 6m 41s
# 175:	learn: 1514.8736942	total: 1m 25s	remaining: 6m 40s
# 176:	learn: 1514.1575451	total: 1m 26s	remaining: 6m 40s
# 177:	learn: 1513.5062507	total: 1m 26s	remaining: 6m 39s
# 178:	learn: 1513.1310502	total: 1m 27s	remaining: 6m 39s
# 179:	learn: 1512.4136173	total: 1m 27s	remaining: 6m 38s
# 180:	learn: 1511.4807509	total: 1m 28s	remaining: 6m 38s
# 181:	learn: 1510.4453300	total: 1m 28s	remaining: 6m 38s
# 182:	learn: 1510.0100514	total: 1m 29s	remaining: 6m 37s
# 183:	learn: 1509.5479135	total: 1m 29s	remaining: 6m 37s
# 184:	learn: 1509.1933756	total: 1m 30s	remaining: 6m 36s
# 185:	learn: 1508.7370181	total: 1m 30s	remaining: 6m 35s
# 186:	learn: 1508.1928040	total: 1m 30s	remaining: 6m 35s
# 187:	learn: 1507.3098070	total: 1m 31s	remaining: 6m 35s
# 188:	learn: 1505.6637227	total: 1m 31s	remaining: 6m 34s
# 189:	learn: 1504.7795459	total: 1m 32s	remaining: 6m 33s
# 190:	learn: 1503.5561333	total: 1m 32s	remaining: 6m 33s
# 191:	learn: 1502.8738642	total: 1m 33s	remaining: 6m 32s
# 192:	learn: 1502.3240912	total: 1m 33s	remaining: 6m 32s
# 193:	learn: 1502.0803269	total: 1m 34s	remaining: 6m 31s
# 194:	learn: 1501.3699794	total: 1m 34s	remaining: 6m 31s
# 195:	learn: 1500.6250963	total: 1m 35s	remaining: 6m 31s
# 196:	learn: 1500.0017151	total: 1m 35s	remaining: 6m 31s
# 197:	learn: 1499.1534403	total: 1m 36s	remaining: 6m 30s
# 198:	learn: 1498.7720654	total: 1m 36s	remaining: 6m 29s
# 199:	learn: 1498.3401984	total: 1m 37s	remaining: 6m 29s
# 200:	learn: 1498.0601962	total: 1m 37s	remaining: 6m 28s
# 201:	learn: 1497.4104517	total: 1m 38s	remaining: 6m 28s
# 202:	learn: 1496.5128028	total: 1m 38s	remaining: 6m 27s
# 203:	learn: 1495.9064051	total: 1m 39s	remaining: 6m 26s
# 204:	learn: 1495.5463228	total: 1m 39s	remaining: 6m 26s
# 205:	learn: 1495.2722962	total: 1m 40s	remaining: 6m 26s
# 206:	learn: 1494.8909964	total: 1m 40s	remaining: 6m 25s
# 207:	learn: 1494.2056347	total: 1m 41s	remaining: 6m 25s
# 208:	learn: 1493.6688831	total: 1m 41s	remaining: 6m 25s
# 209:	learn: 1493.1250302	total: 1m 42s	remaining: 6m 24s
# 210:	learn: 1492.6272314	total: 1m 42s	remaining: 6m 24s
# 211:	learn: 1492.1582632	total: 1m 43s	remaining: 6m 24s
# 212:	learn: 1491.3936581	total: 1m 43s	remaining: 6m 23s
# 213:	learn: 1490.6859268	total: 1m 44s	remaining: 6m 23s
# 214:	learn: 1490.3952939	total: 1m 44s	remaining: 6m 22s
# 215:	learn: 1489.8374967	total: 1m 45s	remaining: 6m 22s
# 216:	learn: 1489.1696139	total: 1m 45s	remaining: 6m 22s
# 217:	learn: 1488.8209166	total: 1m 46s	remaining: 6m 21s
# 218:	learn: 1487.9789296	total: 1m 46s	remaining: 6m 21s
# 219:	learn: 1487.5679378	total: 1m 47s	remaining: 6m 20s
# 220:	learn: 1485.8382596	total: 1m 47s	remaining: 6m 20s
# 221:	learn: 1485.1837167	total: 1m 48s	remaining: 6m 19s
# 222:	learn: 1484.6195771	total: 1m 48s	remaining: 6m 19s
# 223:	learn: 1484.2960427	total: 1m 49s	remaining: 6m 19s
# 224:	learn: 1483.8225759	total: 1m 49s	remaining: 6m 18s
# 225:	learn: 1483.2000382	total: 1m 50s	remaining: 6m 18s
# 226:	learn: 1482.8413987	total: 1m 50s	remaining: 6m 17s
# 227:	learn: 1481.7830015	total: 1m 51s	remaining: 6m 17s
# 228:	learn: 1481.5025681	total: 1m 51s	remaining: 6m 16s
# 229:	learn: 1480.1977111	total: 1m 52s	remaining: 6m 16s
# 230:	learn: 1479.9696902	total: 1m 52s	remaining: 6m 15s
# 231:	learn: 1479.5381462	total: 1m 53s	remaining: 6m 15s
# 232:	learn: 1479.3378037	total: 1m 53s	remaining: 6m 14s
# 233:	learn: 1478.6349632	total: 1m 54s	remaining: 6m 14s
# 234:	learn: 1478.1167380	total: 1m 54s	remaining: 6m 13s
# 235:	learn: 1477.1922004	total: 1m 55s	remaining: 6m 13s
# 236:	learn: 1476.7517582	total: 1m 55s	remaining: 6m 13s
# 237:	learn: 1476.4687407	total: 1m 56s	remaining: 6m 12s
# 238:	learn: 1475.9383282	total: 1m 56s	remaining: 6m 12s
# 239:	learn: 1475.1296450	total: 1m 57s	remaining: 6m 11s
# 240:	learn: 1474.7156482	total: 1m 57s	remaining: 6m 10s
# 241:	learn: 1473.7918786	total: 1m 58s	remaining: 6m 10s
# 242:	learn: 1473.1985611	total: 1m 58s	remaining: 6m 9s
# 243:	learn: 1472.6042659	total: 1m 59s	remaining: 6m 9s
# 244:	learn: 1472.0114671	total: 1m 59s	remaining: 6m 8s
# 245:	learn: 1471.3751991	total: 2m	remaining: 6m 8s
# 246:	learn: 1470.9629860	total: 2m	remaining: 6m 7s
# 247:	learn: 1470.2353739	total: 2m 1s	remaining: 6m 7s
# 248:	learn: 1469.0940362	total: 2m 1s	remaining: 6m 6s
# 249:	learn: 1468.7952322	total: 2m 2s	remaining: 6m 6s
# 250:	learn: 1468.0648654	total: 2m 2s	remaining: 6m 5s
# 251:	learn: 1467.5668713	total: 2m 3s	remaining: 6m 5s
# 252:	learn: 1467.1242788	total: 2m 3s	remaining: 6m 5s
# 253:	learn: 1466.4371755	total: 2m 4s	remaining: 6m 4s
# 254:	learn: 1466.1080715	total: 2m 4s	remaining: 6m 4s
# 255:	learn: 1465.5238940	total: 2m 5s	remaining: 6m 4s
# 256:	learn: 1464.3688866	total: 2m 5s	remaining: 6m 3s
# 257:	learn: 1463.7102310	total: 2m 6s	remaining: 6m 3s
# 258:	learn: 1463.2513812	total: 2m 6s	remaining: 6m 2s
# 259:	learn: 1462.0963258	total: 2m 7s	remaining: 6m 2s
# 260:	learn: 1461.8417182	total: 2m 7s	remaining: 6m 1s
# 261:	learn: 1461.5231950	total: 2m 8s	remaining: 6m 1s
# 262:	learn: 1461.3075442	total: 2m 8s	remaining: 6m
# 263:	learn: 1460.9567537	total: 2m 9s	remaining: 5m 59s
# 264:	learn: 1460.6525646	total: 2m 9s	remaining: 5m 59s
# 265:	learn: 1459.8633591	total: 2m 10s	remaining: 5m 59s
# 266:	learn: 1459.5051346	total: 2m 10s	remaining: 5m 58s
# 267:	learn: 1458.7788604	total: 2m 11s	remaining: 5m 58s
# 268:	learn: 1458.4396288	total: 2m 11s	remaining: 5m 57s
# 269:	learn: 1457.9149250	total: 2m 11s	remaining: 5m 56s
# 270:	learn: 1457.3816066	total: 2m 12s	remaining: 5m 56s
# 271:	learn: 1456.5087507	total: 2m 12s	remaining: 5m 55s
# 272:	learn: 1455.9668930	total: 2m 13s	remaining: 5m 55s
# 273:	learn: 1455.3848365	total: 2m 13s	remaining: 5m 54s
# 274:	learn: 1455.1721799	total: 2m 14s	remaining: 5m 54s
# 275:	learn: 1454.9084257	total: 2m 14s	remaining: 5m 54s
# 276:	learn: 1454.3826737	total: 2m 15s	remaining: 5m 53s
# 277:	learn: 1453.8279407	total: 2m 16s	remaining: 5m 53s
# 278:	learn: 1452.5733693	total: 2m 16s	remaining: 5m 52s
# 279:	learn: 1451.6558554	total: 2m 17s	remaining: 5m 52s
# 280:	learn: 1451.2994179	total: 2m 17s	remaining: 5m 52s
# 281:	learn: 1450.7598904	total: 2m 18s	remaining: 5m 51s
# 282:	learn: 1450.2434438	total: 2m 18s	remaining: 5m 51s
# 283:	learn: 1449.4076122	total: 2m 19s	remaining: 5m 50s
# 284:	learn: 1448.7386645	total: 2m 19s	remaining: 5m 50s
# 285:	learn: 1448.2203155	total: 2m 20s	remaining: 5m 50s
# 286:	learn: 1447.6827201	total: 2m 20s	remaining: 5m 49s
# 287:	learn: 1447.0778244	total: 2m 21s	remaining: 5m 49s
# 288:	learn: 1446.9061269	total: 2m 21s	remaining: 5m 48s
# 289:	learn: 1446.1961769	total: 2m 22s	remaining: 5m 48s
# 290:	learn: 1445.8636179	total: 2m 22s	remaining: 5m 47s
# 291:	learn: 1445.5632401	total: 2m 23s	remaining: 5m 47s
# 292:	learn: 1445.3355070	total: 2m 23s	remaining: 5m 46s
# 293:	learn: 1444.2550400	total: 2m 24s	remaining: 5m 46s
# 294:	learn: 1443.7588249	total: 2m 24s	remaining: 5m 45s
# 295:	learn: 1443.4181974	total: 2m 25s	remaining: 5m 45s
# 296:	learn: 1443.0203620	total: 2m 25s	remaining: 5m 44s
# 297:	learn: 1442.7533264	total: 2m 26s	remaining: 5m 44s
# 298:	learn: 1442.5046260	total: 2m 26s	remaining: 5m 44s
# 299:	learn: 1442.2540555	total: 2m 27s	remaining: 5m 43s
# 300:	learn: 1441.9719433	total: 2m 27s	remaining: 5m 43s
# 301:	learn: 1441.4826776	total: 2m 28s	remaining: 5m 42s
# 302:	learn: 1441.1926945	total: 2m 28s	remaining: 5m 42s
# 303:	learn: 1440.6037422	total: 2m 29s	remaining: 5m 41s
# 304:	learn: 1440.0425418	total: 2m 29s	remaining: 5m 41s
# 305:	learn: 1439.6475074	total: 2m 30s	remaining: 5m 41s
# 306:	learn: 1438.9240257	total: 2m 30s	remaining: 5m 40s
# 307:	learn: 1438.3034496	total: 2m 31s	remaining: 5m 40s
# 308:	learn: 1438.0357044	total: 2m 31s	remaining: 5m 39s
# 309:	learn: 1437.6075277	total: 2m 32s	remaining: 5m 39s
# 310:	learn: 1437.4305659	total: 2m 32s	remaining: 5m 38s
# 311:	learn: 1437.2117416	total: 2m 33s	remaining: 5m 38s
# 312:	learn: 1436.9592678	total: 2m 33s	remaining: 5m 38s
# 313:	learn: 1435.8770428	total: 2m 34s	remaining: 5m 37s
# 314:	learn: 1435.6383993	total: 2m 35s	remaining: 5m 37s
# 315:	learn: 1435.1750854	total: 2m 35s	remaining: 5m 36s
# 316:	learn: 1434.5203058	total: 2m 36s	remaining: 5m 36s
# 317:	learn: 1434.2707875	total: 2m 36s	remaining: 5m 35s
# 318:	learn: 1433.4900910	total: 2m 37s	remaining: 5m 35s
# 319:	learn: 1432.8667580	total: 2m 37s	remaining: 5m 34s
# 320:	learn: 1432.8644445	total: 2m 38s	remaining: 5m 34s
# 321:	learn: 1432.2979623	total: 2m 38s	remaining: 5m 33s
# 322:	learn: 1432.0512948	total: 2m 38s	remaining: 5m 33s
# 323:	learn: 1431.7971655	total: 2m 39s	remaining: 5m 32s
# 324:	learn: 1431.3103774	total: 2m 39s	remaining: 5m 32s
# 325:	learn: 1430.9388735	total: 2m 40s	remaining: 5m 31s
# 326:	learn: 1430.0522599	total: 2m 40s	remaining: 5m 31s
# 327:	learn: 1429.6056419	total: 2m 41s	remaining: 5m 30s
# 328:	learn: 1429.2457431	total: 2m 41s	remaining: 5m 30s
# 329:	learn: 1428.8177528	total: 2m 42s	remaining: 5m 30s
# 330:	learn: 1428.8157011	total: 2m 42s	remaining: 5m 29s
# 331:	learn: 1428.1429682	total: 2m 43s	remaining: 5m 29s
# 332:	learn: 1427.6481693	total: 2m 44s	remaining: 5m 28s
# 333:	learn: 1426.9562602	total: 2m 44s	remaining: 5m 28s
# 334:	learn: 1426.5008673	total: 2m 45s	remaining: 5m 27s
# 335:	learn: 1426.1035957	total: 2m 45s	remaining: 5m 27s
# 336:	learn: 1425.7143963	total: 2m 46s	remaining: 5m 26s
# 337:	learn: 1425.2187497	total: 2m 46s	remaining: 5m 26s
# 338:	learn: 1424.9706339	total: 2m 47s	remaining: 5m 25s
# 339:	learn: 1424.5971174	total: 2m 47s	remaining: 5m 25s
# 340:	learn: 1423.8186012	total: 2m 48s	remaining: 5m 24s
# 341:	learn: 1423.4236348	total: 2m 48s	remaining: 5m 24s
# 342:	learn: 1423.1647763	total: 2m 49s	remaining: 5m 24s
# 343:	learn: 1422.8570885	total: 2m 49s	remaining: 5m 23s
# 344:	learn: 1422.5449371	total: 2m 50s	remaining: 5m 22s
# 345:	learn: 1422.2371514	total: 2m 50s	remaining: 5m 22s
# 346:	learn: 1421.9549418	total: 2m 51s	remaining: 5m 22s
# 347:	learn: 1421.5382330	total: 2m 51s	remaining: 5m 21s
# 348:	learn: 1421.0263452	total: 2m 52s	remaining: 5m 21s
# 349:	learn: 1420.6420676	total: 2m 52s	remaining: 5m 20s
# 350:	learn: 1420.3875881	total: 2m 53s	remaining: 5m 20s
# 351:	learn: 1419.9247640	total: 2m 53s	remaining: 5m 20s
# 352:	learn: 1419.5260642	total: 2m 54s	remaining: 5m 19s
# 353:	learn: 1419.2265480	total: 2m 54s	remaining: 5m 19s
# 354:	learn: 1418.9567203	total: 2m 55s	remaining: 5m 18s
# 355:	learn: 1418.3341040	total: 2m 55s	remaining: 5m 18s
# 356:	learn: 1417.9774483	total: 2m 56s	remaining: 5m 17s
# 357:	learn: 1417.5130248	total: 2m 57s	remaining: 5m 17s
# 358:	learn: 1417.2732457	total: 2m 57s	remaining: 5m 16s
# 359:	learn: 1416.8750957	total: 2m 58s	remaining: 5m 16s
# 360:	learn: 1416.6071697	total: 2m 58s	remaining: 5m 16s
# 361:	learn: 1416.1919347	total: 2m 59s	remaining: 5m 15s
# 362:	learn: 1415.9781931	total: 2m 59s	remaining: 5m 15s
# 363:	learn: 1415.5748639	total: 3m	remaining: 5m 14s
# 364:	learn: 1415.3478894	total: 3m	remaining: 5m 14s
# 365:	learn: 1415.0241831	total: 3m 1s	remaining: 5m 13s
# 366:	learn: 1414.5320690	total: 3m 1s	remaining: 5m 13s
# 367:	learn: 1414.0817552	total: 3m 2s	remaining: 5m 13s
# 368:	learn: 1413.6377397	total: 3m 2s	remaining: 5m 12s
# 369:	learn: 1413.1505651	total: 3m 3s	remaining: 5m 12s
# 370:	learn: 1412.6655832	total: 3m 3s	remaining: 5m 11s
# 371:	learn: 1412.3736349	total: 3m 4s	remaining: 5m 11s
# 372:	learn: 1411.8280560	total: 3m 4s	remaining: 5m 10s
# 373:	learn: 1411.5382751	total: 3m 5s	remaining: 5m 10s
# 374:	learn: 1411.1554657	total: 3m 5s	remaining: 5m 9s
# 375:	learn: 1411.0350642	total: 3m 6s	remaining: 5m 9s
# 376:	learn: 1411.0335963	total: 3m 6s	remaining: 5m 8s
# 377:	learn: 1410.6051847	total: 3m 7s	remaining: 5m 8s
# 378:	learn: 1410.3504912	total: 3m 7s	remaining: 5m 7s
# 379:	learn: 1410.0702488	total: 3m 8s	remaining: 5m 7s
# 380:	learn: 1409.8492540	total: 3m 8s	remaining: 5m 7s
# 381:	learn: 1409.1274191	total: 3m 9s	remaining: 5m 6s
# 382:	learn: 1408.8108165	total: 3m 9s	remaining: 5m 6s
# 383:	learn: 1408.2041468	total: 3m 10s	remaining: 5m 5s
# 384:	learn: 1407.8856477	total: 3m 10s	remaining: 5m 4s
# 385:	learn: 1407.7147511	total: 3m 11s	remaining: 5m 4s
# 386:	learn: 1406.5543117	total: 3m 11s	remaining: 5m 3s
# 387:	learn: 1405.9278685	total: 3m 12s	remaining: 5m 3s
# 388:	learn: 1405.3959117	total: 3m 13s	remaining: 5m 3s
# 389:	learn: 1404.9260461	total: 3m 13s	remaining: 5m 2s
# 390:	learn: 1404.5354563	total: 3m 13s	remaining: 5m 2s
# 391:	learn: 1403.7667715	total: 3m 14s	remaining: 5m 1s
# 392:	learn: 1403.3649971	total: 3m 15s	remaining: 5m 1s
# 393:	learn: 1403.0042632	total: 3m 15s	remaining: 5m
# 394:	learn: 1402.3334722	total: 3m 16s	remaining: 5m
# 395:	learn: 1402.0217350	total: 3m 16s	remaining: 4m 59s
# 396:	learn: 1401.6683151	total: 3m 17s	remaining: 4m 59s
# 397:	learn: 1400.7359706	total: 3m 17s	remaining: 4m 58s
# 398:	learn: 1400.6060500	total: 3m 18s	remaining: 4m 58s
# 399:	learn: 1400.3660423	total: 3m 18s	remaining: 4m 57s
# 400:	learn: 1399.8867268	total: 3m 19s	remaining: 4m 57s
# 401:	learn: 1399.3754144	total: 3m 19s	remaining: 4m 57s
# 402:	learn: 1399.2564243	total: 3m 20s	remaining: 4m 56s
# 403:	learn: 1398.5103307	total: 3m 20s	remaining: 4m 56s
# 404:	learn: 1398.1068998	total: 3m 21s	remaining: 4m 55s
# 405:	learn: 1397.3991026	total: 3m 21s	remaining: 4m 55s
# 406:	learn: 1397.0911756	total: 3m 22s	remaining: 4m 54s
# 407:	learn: 1396.8839325	total: 3m 22s	remaining: 4m 54s
# 408:	learn: 1396.4075031	total: 3m 23s	remaining: 4m 53s
# 409:	learn: 1395.8322638	total: 3m 23s	remaining: 4m 53s
# 410:	learn: 1395.3866161	total: 3m 24s	remaining: 4m 53s
# 411:	learn: 1395.0534820	total: 3m 25s	remaining: 4m 52s
# 412:	learn: 1394.7665786	total: 3m 25s	remaining: 4m 52s
# 413:	learn: 1394.3802888	total: 3m 26s	remaining: 4m 51s
# 414:	learn: 1393.8722960	total: 3m 26s	remaining: 4m 51s
# 415:	learn: 1393.6635227	total: 3m 27s	remaining: 4m 50s
# 416:	learn: 1393.2809900	total: 3m 27s	remaining: 4m 50s
# 417:	learn: 1392.7563976	total: 3m 28s	remaining: 4m 49s
# 418:	learn: 1392.4076302	total: 3m 28s	remaining: 4m 49s
# 419:	learn: 1391.8285929	total: 3m 29s	remaining: 4m 48s
# 420:	learn: 1391.5073528	total: 3m 29s	remaining: 4m 48s
# 421:	learn: 1391.1749416	total: 3m 30s	remaining: 4m 48s
# 422:	learn: 1390.5736317	total: 3m 30s	remaining: 4m 47s
# 423:	learn: 1390.3849055	total: 3m 31s	remaining: 4m 47s
# 424:	learn: 1389.9550897	total: 3m 31s	remaining: 4m 46s
# 425:	learn: 1389.6172468	total: 3m 32s	remaining: 4m 46s
# 426:	learn: 1389.1226108	total: 3m 33s	remaining: 4m 45s
# 427:	learn: 1388.8278064	total: 3m 33s	remaining: 4m 45s
# 428:	learn: 1388.2661326	total: 3m 34s	remaining: 4m 45s
# 429:	learn: 1387.9159170	total: 3m 34s	remaining: 4m 44s
# 430:	learn: 1387.4504348	total: 3m 35s	remaining: 4m 44s
# 431:	learn: 1387.2376161	total: 3m 35s	remaining: 4m 43s
# 432:	learn: 1387.0410559	total: 3m 36s	remaining: 4m 43s
# 433:	learn: 1386.8712997	total: 3m 36s	remaining: 4m 42s
# 434:	learn: 1386.5522329	total: 3m 37s	remaining: 4m 41s
# 435:	learn: 1386.2330387	total: 3m 37s	remaining: 4m 41s
# 436:	learn: 1385.8533063	total: 3m 38s	remaining: 4m 40s
# 437:	learn: 1385.3543390	total: 3m 38s	remaining: 4m 40s
# 438:	learn: 1385.0656081	total: 3m 39s	remaining: 4m 40s
# 439:	learn: 1384.7964273	total: 3m 39s	remaining: 4m 39s
# 440:	learn: 1384.5249072	total: 3m 40s	remaining: 4m 39s
# 441:	learn: 1384.2066410	total: 3m 40s	remaining: 4m 38s
# 442:	learn: 1383.9183832	total: 3m 41s	remaining: 4m 38s
# 443:	learn: 1383.5321516	total: 3m 41s	remaining: 4m 37s
# 444:	learn: 1383.3735917	total: 3m 42s	remaining: 4m 37s
# 445:	learn: 1383.1457582	total: 3m 42s	remaining: 4m 36s
# 446:	learn: 1383.0312184	total: 3m 43s	remaining: 4m 35s
# 447:	learn: 1382.5921696	total: 3m 43s	remaining: 4m 35s
# 448:	learn: 1382.5747119	total: 3m 44s	remaining: 4m 35s
# 449:	learn: 1382.3721511	total: 3m 44s	remaining: 4m 34s
# 450:	learn: 1382.2600100	total: 3m 45s	remaining: 4m 34s
# 451:	learn: 1381.8105823	total: 3m 45s	remaining: 4m 33s
# 452:	learn: 1381.5841657	total: 3m 46s	remaining: 4m 33s
# 453:	learn: 1381.2619802	total: 3m 46s	remaining: 4m 32s
# 454:	learn: 1380.8895976	total: 3m 47s	remaining: 4m 32s
# 455:	learn: 1380.3244049	total: 3m 47s	remaining: 4m 31s
# 456:	learn: 1379.8167172	total: 3m 48s	remaining: 4m 31s
# 457:	learn: 1379.7937641	total: 3m 48s	remaining: 4m 30s
# 458:	learn: 1379.1243224	total: 3m 49s	remaining: 4m 30s
# 459:	learn: 1378.5829952	total: 3m 49s	remaining: 4m 29s
# 460:	learn: 1378.3890238	total: 3m 50s	remaining: 4m 28s
# 461:	learn: 1378.2256232	total: 3m 50s	remaining: 4m 28s
# 462:	learn: 1377.8640532	total: 3m 51s	remaining: 4m 27s
# 463:	learn: 1377.4716949	total: 3m 51s	remaining: 4m 27s
# 464:	learn: 1376.9103437	total: 3m 52s	remaining: 4m 26s
# 465:	learn: 1376.5685100	total: 3m 52s	remaining: 4m 26s
# 466:	learn: 1376.1724520	total: 3m 53s	remaining: 4m 25s
# 467:	learn: 1375.4414072	total: 3m 53s	remaining: 4m 25s
# 468:	learn: 1374.9923172	total: 3m 54s	remaining: 4m 24s
# 469:	learn: 1374.9157259	total: 3m 54s	remaining: 4m 24s
# 470:	learn: 1374.6174598	total: 3m 55s	remaining: 4m 23s
# 471:	learn: 1374.2404558	total: 3m 55s	remaining: 4m 23s
# 472:	learn: 1373.9884949	total: 3m 56s	remaining: 4m 23s
# 473:	learn: 1373.5523738	total: 3m 56s	remaining: 4m 22s
# 474:	learn: 1373.1967621	total: 3m 57s	remaining: 4m 21s
# 475:	learn: 1373.0746016	total: 3m 57s	remaining: 4m 21s
# 476:	learn: 1372.5811425	total: 3m 58s	remaining: 4m 21s
# 477:	learn: 1372.4356142	total: 3m 58s	remaining: 4m 20s
# 478:	learn: 1372.0739058	total: 3m 59s	remaining: 4m 20s
# 479:	learn: 1371.8019632	total: 3m 59s	remaining: 4m 19s
# 480:	learn: 1371.6733817	total: 4m	remaining: 4m 18s
# 481:	learn: 1371.3963091	total: 4m	remaining: 4m 18s
# 482:	learn: 1371.1701405	total: 4m 1s	remaining: 4m 18s
# 483:	learn: 1370.8513025	total: 4m 1s	remaining: 4m 17s
# 484:	learn: 1370.5487665	total: 4m 2s	remaining: 4m 17s
# 485:	learn: 1370.2079410	total: 4m 2s	remaining: 4m 16s
# 486:	learn: 1369.9209033	total: 4m 3s	remaining: 4m 16s
# 487:	learn: 1369.7860922	total: 4m 3s	remaining: 4m 15s
# 488:	learn: 1369.5933124	total: 4m 4s	remaining: 4m 15s
# 489:	learn: 1369.3749705	total: 4m 4s	remaining: 4m 14s
# 490:	learn: 1368.8754168	total: 4m 5s	remaining: 4m 14s
# 491:	learn: 1368.6749999	total: 4m 5s	remaining: 4m 13s
# 492:	learn: 1368.1625265	total: 4m 6s	remaining: 4m 13s
# 493:	learn: 1367.9415107	total: 4m 6s	remaining: 4m 12s
# 494:	learn: 1367.7295518	total: 4m 7s	remaining: 4m 12s
# 495:	learn: 1367.3475393	total: 4m 7s	remaining: 4m 11s
# 496:	learn: 1367.0911950	total: 4m 8s	remaining: 4m 11s
# 497:	learn: 1366.6818872	total: 4m 8s	remaining: 4m 10s
# 498:	learn: 1366.3111996	total: 4m 9s	remaining: 4m 10s
# 499:	learn: 1366.1919401	total: 4m 9s	remaining: 4m 9s
# 500:	learn: 1366.0558675	total: 4m 10s	remaining: 4m 9s
# 501:	learn: 1365.7592840	total: 4m 10s	remaining: 4m 8s
# 502:	learn: 1365.2853387	total: 4m 11s	remaining: 4m 8s
# 503:	learn: 1365.1744259	total: 4m 11s	remaining: 4m 7s
# 504:	learn: 1364.6636002	total: 4m 12s	remaining: 4m 7s
# 505:	learn: 1364.5037625	total: 4m 12s	remaining: 4m 6s
# 506:	learn: 1364.3207462	total: 4m 13s	remaining: 4m 6s
# 507:	learn: 1364.0057270	total: 4m 14s	remaining: 4m 6s
# 508:	learn: 1363.4132332	total: 4m 14s	remaining: 4m 5s
# 509:	learn: 1362.8775239	total: 4m 15s	remaining: 4m 5s
# 510:	learn: 1362.5250392	total: 4m 15s	remaining: 4m 4s
# 511:	learn: 1362.2632478	total: 4m 16s	remaining: 4m 4s
# 512:	learn: 1361.7588416	total: 4m 16s	remaining: 4m 3s
# 513:	learn: 1361.4531451	total: 4m 17s	remaining: 4m 3s
# 514:	learn: 1361.1873649	total: 4m 17s	remaining: 4m 2s
# 515:	learn: 1360.9296869	total: 4m 18s	remaining: 4m 2s
# 516:	learn: 1360.2411625	total: 4m 18s	remaining: 4m 1s
# 517:	learn: 1359.8598046	total: 4m 19s	remaining: 4m 1s
# 518:	learn: 1359.6188652	total: 4m 19s	remaining: 4m
# 519:	learn: 1359.3690130	total: 4m 20s	remaining: 4m
# 520:	learn: 1359.2399597	total: 4m 20s	remaining: 3m 59s
# 521:	learn: 1358.9047423	total: 4m 21s	remaining: 3m 59s
# 522:	learn: 1358.7004836	total: 4m 21s	remaining: 3m 58s
# 523:	learn: 1358.5507941	total: 4m 22s	remaining: 3m 58s
# 524:	learn: 1358.2341533	total: 4m 22s	remaining: 3m 57s
# 525:	learn: 1357.9274531	total: 4m 23s	remaining: 3m 57s
# 526:	learn: 1357.4196831	total: 4m 24s	remaining: 3m 56s
# 527:	learn: 1356.9965752	total: 4m 24s	remaining: 3m 56s
# 528:	learn: 1356.7892562	total: 4m 25s	remaining: 3m 56s
# 529:	learn: 1356.5971490	total: 4m 25s	remaining: 3m 55s
# 530:	learn: 1356.4324368	total: 4m 26s	remaining: 3m 55s
# 531:	learn: 1355.8248483	total: 4m 26s	remaining: 3m 54s
# 532:	learn: 1355.3719403	total: 4m 27s	remaining: 3m 54s
# 533:	learn: 1355.2032251	total: 4m 27s	remaining: 3m 53s
# 534:	learn: 1355.0129887	total: 4m 28s	remaining: 3m 53s
# 535:	learn: 1354.8036925	total: 4m 28s	remaining: 3m 52s
# 536:	learn: 1354.5266638	total: 4m 29s	remaining: 3m 52s
# 537:	learn: 1354.2949785	total: 4m 29s	remaining: 3m 51s
# 538:	learn: 1354.1329446	total: 4m 30s	remaining: 3m 51s
# 539:	learn: 1353.6717254	total: 4m 30s	remaining: 3m 50s
# 540:	learn: 1353.1132087	total: 4m 31s	remaining: 3m 50s
# 541:	learn: 1352.8147140	total: 4m 31s	remaining: 3m 49s
# 542:	learn: 1352.3725617	total: 4m 32s	remaining: 3m 49s
# 543:	learn: 1352.1186609	total: 4m 33s	remaining: 3m 48s
# 544:	learn: 1351.8904891	total: 4m 33s	remaining: 3m 48s
# 545:	learn: 1351.8043500	total: 4m 34s	remaining: 3m 47s
# 546:	learn: 1351.5920394	total: 4m 34s	remaining: 3m 47s
# 547:	learn: 1351.0463651	total: 4m 35s	remaining: 3m 47s
# 548:	learn: 1350.7359227	total: 4m 35s	remaining: 3m 46s
# 549:	learn: 1350.4959093	total: 4m 36s	remaining: 3m 46s
# 550:	learn: 1350.2468529	total: 4m 36s	remaining: 3m 45s
# 551:	learn: 1350.0786473	total: 4m 37s	remaining: 3m 45s
# 552:	learn: 1349.7704266	total: 4m 38s	remaining: 3m 44s
# 553:	learn: 1349.4950423	total: 4m 38s	remaining: 3m 44s
# 554:	learn: 1349.3886560	total: 4m 39s	remaining: 3m 43s
# 555:	learn: 1349.1776336	total: 4m 39s	remaining: 3m 43s
# 556:	learn: 1348.5269150	total: 4m 40s	remaining: 3m 42s
# 557:	learn: 1348.3651832	total: 4m 40s	remaining: 3m 42s
# 558:	learn: 1348.0811890	total: 4m 40s	remaining: 3m 41s
# 559:	learn: 1347.9076193	total: 4m 41s	remaining: 3m 41s
# 560:	learn: 1347.5091464	total: 4m 42s	remaining: 3m 40s
# 561:	learn: 1346.8951899	total: 4m 42s	remaining: 3m 40s
# 562:	learn: 1346.7434296	total: 4m 42s	remaining: 3m 39s
# 563:	learn: 1346.3771494	total: 4m 43s	remaining: 3m 39s
# 564:	learn: 1346.1819226	total: 4m 44s	remaining: 3m 38s
# 565:	learn: 1345.8837256	total: 4m 44s	remaining: 3m 38s
# 566:	learn: 1345.4324156	total: 4m 45s	remaining: 3m 37s
# 567:	learn: 1344.8414081	total: 4m 45s	remaining: 3m 37s
# 568:	learn: 1344.6548573	total: 4m 46s	remaining: 3m 36s
# 569:	learn: 1344.3895384	total: 4m 46s	remaining: 3m 36s
# 570:	learn: 1344.1802357	total: 4m 47s	remaining: 3m 35s
# 571:	learn: 1343.7039521	total: 4m 47s	remaining: 3m 35s
# 572:	learn: 1343.4685476	total: 4m 48s	remaining: 3m 34s
# 573:	learn: 1342.9077285	total: 4m 48s	remaining: 3m 34s
# 574:	learn: 1342.4062070	total: 4m 49s	remaining: 3m 33s
# 575:	learn: 1342.1793472	total: 4m 49s	remaining: 3m 33s
# 576:	learn: 1341.9762888	total: 4m 50s	remaining: 3m 32s
# 577:	learn: 1341.4215777	total: 4m 50s	remaining: 3m 32s
# 578:	learn: 1341.0636939	total: 4m 51s	remaining: 3m 31s
# 579:	learn: 1340.9476573	total: 4m 51s	remaining: 3m 31s
# 580:	learn: 1340.7541170	total: 4m 52s	remaining: 3m 30s
# 581:	learn: 1340.5387459	total: 4m 53s	remaining: 3m 30s
# 582:	learn: 1340.2021910	total: 4m 53s	remaining: 3m 30s
# 583:	learn: 1339.9902175	total: 4m 54s	remaining: 3m 29s
# 584:	learn: 1339.5110294	total: 4m 54s	remaining: 3m 29s
# 585:	learn: 1339.4541417	total: 4m 55s	remaining: 3m 28s
# 586:	learn: 1339.3597550	total: 4m 55s	remaining: 3m 28s
# 587:	learn: 1338.8760448	total: 4m 56s	remaining: 3m 27s
# 588:	learn: 1338.5989197	total: 4m 56s	remaining: 3m 27s
# 589:	learn: 1338.4251145	total: 4m 57s	remaining: 3m 26s
# 590:	learn: 1338.1872845	total: 4m 57s	remaining: 3m 26s
# 591:	learn: 1337.9756260	total: 4m 58s	remaining: 3m 25s
# 592:	learn: 1337.7537017	total: 4m 58s	remaining: 3m 25s
# 593:	learn: 1337.6288153	total: 4m 59s	remaining: 3m 24s
# 594:	learn: 1337.4700514	total: 4m 59s	remaining: 3m 24s
# 595:	learn: 1337.3670959	total: 5m	remaining: 3m 23s
# 596:	learn: 1337.2413021	total: 5m 1s	remaining: 3m 23s
# 597:	learn: 1337.0843384	total: 5m 1s	remaining: 3m 22s
# 598:	learn: 1336.4978001	total: 5m 2s	remaining: 3m 22s
# 599:	learn: 1336.3691085	total: 5m 2s	remaining: 3m 21s
# 600:	learn: 1336.3540227	total: 5m 3s	remaining: 3m 21s
# 601:	learn: 1336.0773360	total: 5m 3s	remaining: 3m 20s
# 602:	learn: 1335.8045408	total: 5m 4s	remaining: 3m 20s
# 603:	learn: 1335.6345228	total: 5m 4s	remaining: 3m 19s
# 604:	learn: 1335.5063346	total: 5m 5s	remaining: 3m 19s
# 605:	learn: 1335.3952814	total: 5m 5s	remaining: 3m 18s
# 606:	learn: 1335.1794144	total: 5m 6s	remaining: 3m 18s
# 607:	learn: 1334.9000869	total: 5m 6s	remaining: 3m 17s
# 608:	learn: 1334.5928335	total: 5m 7s	remaining: 3m 17s
# 609:	learn: 1334.0533453	total: 5m 7s	remaining: 3m 16s
# 610:	learn: 1333.6110332	total: 5m 8s	remaining: 3m 16s
# 611:	learn: 1333.4568346	total: 5m 8s	remaining: 3m 15s
# 612:	learn: 1333.2710753	total: 5m 9s	remaining: 3m 15s
# 613:	learn: 1333.0748688	total: 5m 9s	remaining: 3m 14s
# 614:	learn: 1332.8307490	total: 5m 10s	remaining: 3m 14s
# 615:	learn: 1332.6320953	total: 5m 10s	remaining: 3m 13s
# 616:	learn: 1332.3130689	total: 5m 11s	remaining: 3m 13s
# 617:	learn: 1332.2672033	total: 5m 12s	remaining: 3m 12s
# 618:	learn: 1331.6959923	total: 5m 12s	remaining: 3m 12s
# 619:	learn: 1331.3689008	total: 5m 13s	remaining: 3m 11s
# 620:	learn: 1331.0424975	total: 5m 13s	remaining: 3m 11s
# 621:	learn: 1330.8461313	total: 5m 14s	remaining: 3m 10s
# 622:	learn: 1330.5252094	total: 5m 14s	remaining: 3m 10s
# 623:	learn: 1330.3045179	total: 5m 15s	remaining: 3m 9s
# 624:	learn: 1329.8348250	total: 5m 15s	remaining: 3m 9s
# 625:	learn: 1329.5783194	total: 5m 16s	remaining: 3m 8s
# 626:	learn: 1329.1422978	total: 5m 16s	remaining: 3m 8s
# 627:	learn: 1328.8654872	total: 5m 17s	remaining: 3m 7s
# 628:	learn: 1328.4199285	total: 5m 17s	remaining: 3m 7s
# 629:	learn: 1328.2694947	total: 5m 18s	remaining: 3m 7s
# 630:	learn: 1327.7536240	total: 5m 18s	remaining: 3m 6s
# 631:	learn: 1327.4014566	total: 5m 19s	remaining: 3m 6s
# 632:	learn: 1327.2372621	total: 5m 19s	remaining: 3m 5s
# 633:	learn: 1326.9651198	total: 5m 20s	remaining: 3m 5s
# 634:	learn: 1326.8760502	total: 5m 21s	remaining: 3m 4s
# 635:	learn: 1326.6472060	total: 5m 21s	remaining: 3m 4s
# 636:	learn: 1326.3904933	total: 5m 22s	remaining: 3m 3s
# 637:	learn: 1326.0465384	total: 5m 22s	remaining: 3m 3s
# 638:	learn: 1325.7440156	total: 5m 23s	remaining: 3m 2s
# 639:	learn: 1325.5757195	total: 5m 23s	remaining: 3m 2s
# 640:	learn: 1325.3723906	total: 5m 24s	remaining: 3m 1s
# 641:	learn: 1324.9471423	total: 5m 24s	remaining: 3m 1s
# 642:	learn: 1324.5595274	total: 5m 25s	remaining: 3m
# 643:	learn: 1324.3922848	total: 5m 25s	remaining: 3m
# 644:	learn: 1324.1784121	total: 5m 26s	remaining: 2m 59s
# 645:	learn: 1323.9658097	total: 5m 26s	remaining: 2m 59s
# 646:	learn: 1323.7228550	total: 5m 27s	remaining: 2m 58s
# 647:	learn: 1323.3394029	total: 5m 28s	remaining: 2m 58s
# 648:	learn: 1323.0898186	total: 5m 28s	remaining: 2m 57s
# 649:	learn: 1322.5606156	total: 5m 29s	remaining: 2m 57s
# 650:	learn: 1322.2545811	total: 5m 29s	remaining: 2m 56s
# 651:	learn: 1321.8532771	total: 5m 30s	remaining: 2m 56s
# 652:	learn: 1321.6688835	total: 5m 30s	remaining: 2m 55s
# 653:	learn: 1321.5121467	total: 5m 31s	remaining: 2m 55s
# 654:	learn: 1321.3470157	total: 5m 31s	remaining: 2m 54s
# 655:	learn: 1320.9229826	total: 5m 32s	remaining: 2m 54s
# 656:	learn: 1320.7329690	total: 5m 32s	remaining: 2m 53s
# 657:	learn: 1320.2303589	total: 5m 33s	remaining: 2m 53s
# 658:	learn: 1320.0359860	total: 5m 33s	remaining: 2m 52s
# 659:	learn: 1319.9116281	total: 5m 34s	remaining: 2m 52s
# 660:	learn: 1319.7248201	total: 5m 34s	remaining: 2m 51s
# 661:	learn: 1319.6232204	total: 5m 35s	remaining: 2m 51s
# 662:	learn: 1318.8314063	total: 5m 35s	remaining: 2m 50s
# 663:	learn: 1318.4689681	total: 5m 36s	remaining: 2m 50s
# 664:	learn: 1318.0455121	total: 5m 36s	remaining: 2m 49s
# 665:	learn: 1317.6893306	total: 5m 37s	remaining: 2m 49s
# 666:	learn: 1317.5373172	total: 5m 37s	remaining: 2m 48s
# 667:	learn: 1317.2699843	total: 5m 38s	remaining: 2m 48s
# 668:	learn: 1316.6624939	total: 5m 39s	remaining: 2m 47s
# 669:	learn: 1316.4172288	total: 5m 39s	remaining: 2m 47s
# 670:	learn: 1316.1634448	total: 5m 40s	remaining: 2m 46s
# 671:	learn: 1315.9400877	total: 5m 40s	remaining: 2m 46s
# 672:	learn: 1315.7869985	total: 5m 41s	remaining: 2m 45s
# 673:	learn: 1315.5346206	total: 5m 41s	remaining: 2m 45s
# 674:	learn: 1315.2200478	total: 5m 42s	remaining: 2m 44s
# 675:	learn: 1314.8799135	total: 5m 42s	remaining: 2m 44s
# 676:	learn: 1314.7469016	total: 5m 43s	remaining: 2m 43s
# 677:	learn: 1314.3261214	total: 5m 43s	remaining: 2m 43s
# 678:	learn: 1314.0691162	total: 5m 44s	remaining: 2m 42s
# 679:	learn: 1313.8228563	total: 5m 44s	remaining: 2m 42s
# 680:	learn: 1313.7179489	total: 5m 45s	remaining: 2m 41s
# 681:	learn: 1313.5863653	total: 5m 45s	remaining: 2m 41s
# 682:	learn: 1313.3236078	total: 5m 46s	remaining: 2m 40s
# 683:	learn: 1313.0343814	total: 5m 46s	remaining: 2m 40s
# 684:	learn: 1312.9508096	total: 5m 47s	remaining: 2m 39s
# 685:	learn: 1312.7321088	total: 5m 47s	remaining: 2m 39s
# 686:	learn: 1312.6540526	total: 5m 48s	remaining: 2m 38s
# 687:	learn: 1312.4531066	total: 5m 49s	remaining: 2m 38s
# 688:	learn: 1312.0750612	total: 5m 49s	remaining: 2m 37s
# 689:	learn: 1311.7766582	total: 5m 50s	remaining: 2m 37s
# 690:	learn: 1311.4667105	total: 5m 50s	remaining: 2m 36s
# 691:	learn: 1311.3277488	total: 5m 51s	remaining: 2m 36s
# 692:	learn: 1311.2896664	total: 5m 51s	remaining: 2m 35s
# 693:	learn: 1310.9092592	total: 5m 52s	remaining: 2m 35s
# 694:	learn: 1310.5630346	total: 5m 52s	remaining: 2m 34s
# 695:	learn: 1309.8999969	total: 5m 53s	remaining: 2m 34s
# 696:	learn: 1309.7907942	total: 5m 53s	remaining: 2m 33s
# 697:	learn: 1309.5260061	total: 5m 54s	remaining: 2m 33s
# 698:	learn: 1309.4562367	total: 5m 55s	remaining: 2m 32s
# 699:	learn: 1309.2458155	total: 5m 55s	remaining: 2m 32s
# 700:	learn: 1308.9745516	total: 5m 56s	remaining: 2m 31s
# 701:	learn: 1308.8703500	total: 5m 56s	remaining: 2m 31s
# 702:	learn: 1308.6913366	total: 5m 57s	remaining: 2m 30s
# 703:	learn: 1308.4979368	total: 5m 57s	remaining: 2m 30s
# 704:	learn: 1308.2537784	total: 5m 58s	remaining: 2m 29s
# 705:	learn: 1307.9759941	total: 5m 58s	remaining: 2m 29s
# 706:	learn: 1307.7858747	total: 5m 59s	remaining: 2m 28s
# 707:	learn: 1307.6821815	total: 5m 59s	remaining: 2m 28s
# 708:	learn: 1307.5346788	total: 6m	remaining: 2m 27s
# 709:	learn: 1307.3030989	total: 6m	remaining: 2m 27s
# 710:	learn: 1307.0839816	total: 6m 1s	remaining: 2m 26s
# 711:	learn: 1306.9286147	total: 6m 1s	remaining: 2m 26s
# 712:	learn: 1306.7186727	total: 6m 2s	remaining: 2m 25s
# 713:	learn: 1306.3813085	total: 6m 2s	remaining: 2m 25s
# 714:	learn: 1306.1993722	total: 6m 3s	remaining: 2m 24s
# 715:	learn: 1306.0643380	total: 6m 4s	remaining: 2m 24s
# 716:	learn: 1305.9865118	total: 6m 4s	remaining: 2m 23s
# 717:	learn: 1305.7736531	total: 6m 5s	remaining: 2m 23s
# 718:	learn: 1305.6086687	total: 6m 5s	remaining: 2m 22s
# 719:	learn: 1305.3562246	total: 6m 6s	remaining: 2m 22s
# 720:	learn: 1305.1650600	total: 6m 6s	remaining: 2m 21s
# 721:	learn: 1305.0266693	total: 6m 7s	remaining: 2m 21s
# 722:	learn: 1304.7678318	total: 6m 7s	remaining: 2m 20s
# 723:	learn: 1304.5572387	total: 6m 8s	remaining: 2m 20s
# 724:	learn: 1304.4439294	total: 6m 8s	remaining: 2m 19s
# 725:	learn: 1304.1199895	total: 6m 9s	remaining: 2m 19s
# 726:	learn: 1303.9177407	total: 6m 9s	remaining: 2m 18s
# 727:	learn: 1303.7695798	total: 6m 10s	remaining: 2m 18s
# 728:	learn: 1303.5850751	total: 6m 11s	remaining: 2m 17s
# 729:	learn: 1303.3582340	total: 6m 11s	remaining: 2m 17s
# 730:	learn: 1303.2330793	total: 6m 12s	remaining: 2m 16s
# 731:	learn: 1302.9934193	total: 6m 12s	remaining: 2m 16s
# 732:	learn: 1302.9562402	total: 6m 13s	remaining: 2m 15s
# 733:	learn: 1302.8794156	total: 6m 13s	remaining: 2m 15s
# 734:	learn: 1302.5923384	total: 6m 14s	remaining: 2m 14s
# 735:	learn: 1302.2442351	total: 6m 14s	remaining: 2m 14s
# 736:	learn: 1302.1059554	total: 6m 15s	remaining: 2m 13s
# 737:	learn: 1301.7692514	total: 6m 15s	remaining: 2m 13s
# 738:	learn: 1301.6351553	total: 6m 16s	remaining: 2m 12s
# 739:	learn: 1301.3455614	total: 6m 16s	remaining: 2m 12s
# 740:	learn: 1301.1237847	total: 6m 17s	remaining: 2m 11s
# 741:	learn: 1300.9334577	total: 6m 17s	remaining: 2m 11s
# 742:	learn: 1300.6987370	total: 6m 18s	remaining: 2m 10s
# 743:	learn: 1300.3906851	total: 6m 18s	remaining: 2m 10s
# 744:	learn: 1300.1283080	total: 6m 19s	remaining: 2m 9s
# 745:	learn: 1299.7869505	total: 6m 19s	remaining: 2m 9s
# 746:	learn: 1299.5637366	total: 6m 20s	remaining: 2m 8s
# 747:	learn: 1299.2537363	total: 6m 20s	remaining: 2m 8s
# 748:	learn: 1299.0953728	total: 6m 21s	remaining: 2m 7s
# 749:	learn: 1298.7844454	total: 6m 21s	remaining: 2m 7s
# 750:	learn: 1298.1783882	total: 6m 22s	remaining: 2m 6s
# 751:	learn: 1298.0946322	total: 6m 22s	remaining: 2m 6s
# 752:	learn: 1297.9565093	total: 6m 23s	remaining: 2m 5s
# 753:	learn: 1297.8001732	total: 6m 24s	remaining: 2m 5s
# 754:	learn: 1297.5971295	total: 6m 24s	remaining: 2m 4s
# 755:	learn: 1297.2778959	total: 6m 25s	remaining: 2m 4s
# 756:	learn: 1297.0158043	total: 6m 25s	remaining: 2m 3s
# 757:	learn: 1296.6833842	total: 6m 26s	remaining: 2m 3s
# 758:	learn: 1296.5478769	total: 6m 26s	remaining: 2m 2s
# 759:	learn: 1296.1195502	total: 6m 27s	remaining: 2m 2s
# 760:	learn: 1295.6885598	total: 6m 27s	remaining: 2m 1s
# 761:	learn: 1295.3618874	total: 6m 28s	remaining: 2m 1s
# 762:	learn: 1295.0581473	total: 6m 28s	remaining: 2m
# 763:	learn: 1294.8872726	total: 6m 29s	remaining: 2m
# 764:	learn: 1294.7865188	total: 6m 30s	remaining: 1m 59s
# 765:	learn: 1294.6145431	total: 6m 30s	remaining: 1m 59s
# 766:	learn: 1294.4110594	total: 6m 31s	remaining: 1m 58s
# 767:	learn: 1294.2185944	total: 6m 31s	remaining: 1m 58s
# 768:	learn: 1294.0435685	total: 6m 32s	remaining: 1m 57s
# 769:	learn: 1293.5092495	total: 6m 32s	remaining: 1m 57s
# 770:	learn: 1293.3820028	total: 6m 33s	remaining: 1m 56s
# 771:	learn: 1293.1126981	total: 6m 34s	remaining: 1m 56s
# 772:	learn: 1293.0127348	total: 6m 34s	remaining: 1m 55s
# 773:	learn: 1292.8308161	total: 6m 35s	remaining: 1m 55s
# 774:	learn: 1292.5460182	total: 6m 35s	remaining: 1m 54s
# 775:	learn: 1292.3556359	total: 6m 36s	remaining: 1m 54s
# 776:	learn: 1292.2242967	total: 6m 36s	remaining: 1m 53s
# 777:	learn: 1291.9743217	total: 6m 37s	remaining: 1m 53s
# 778:	learn: 1291.6496114	total: 6m 37s	remaining: 1m 52s
# 779:	learn: 1291.4511470	total: 6m 38s	remaining: 1m 52s
# 780:	learn: 1291.2526392	total: 6m 38s	remaining: 1m 51s
# 781:	learn: 1291.1140600	total: 6m 39s	remaining: 1m 51s
# 782:	learn: 1290.6308372	total: 6m 40s	remaining: 1m 50s
# 783:	learn: 1290.4828352	total: 6m 40s	remaining: 1m 50s
# 784:	learn: 1290.0624105	total: 6m 41s	remaining: 1m 49s
# 785:	learn: 1290.0233912	total: 6m 41s	remaining: 1m 49s
# 786:	learn: 1289.8383776	total: 6m 42s	remaining: 1m 48s
# 787:	learn: 1289.4431904	total: 6m 42s	remaining: 1m 48s
# 788:	learn: 1289.3595227	total: 6m 43s	remaining: 1m 47s
# 789:	learn: 1289.1395518	total: 6m 43s	remaining: 1m 47s
# 790:	learn: 1289.0290893	total: 6m 44s	remaining: 1m 46s
# 791:	learn: 1288.7817524	total: 6m 44s	remaining: 1m 46s
# 792:	learn: 1288.5622505	total: 6m 45s	remaining: 1m 45s
# 793:	learn: 1288.4169655	total: 6m 45s	remaining: 1m 45s
# 794:	learn: 1288.2408406	total: 6m 46s	remaining: 1m 44s
# 795:	learn: 1287.9312292	total: 6m 46s	remaining: 1m 44s
# 796:	learn: 1287.8162840	total: 6m 47s	remaining: 1m 43s
# 797:	learn: 1287.6080844	total: 6m 47s	remaining: 1m 43s
# 798:	learn: 1287.4923227	total: 6m 48s	remaining: 1m 42s
# 799:	learn: 1287.3847482	total: 6m 48s	remaining: 1m 42s
# 800:	learn: 1287.2489731	total: 6m 49s	remaining: 1m 41s
# 801:	learn: 1286.9548774	total: 6m 49s	remaining: 1m 41s
# 802:	learn: 1286.8502127	total: 6m 50s	remaining: 1m 40s
# 803:	learn: 1286.5022976	total: 6m 51s	remaining: 1m 40s
# 804:	learn: 1286.4196162	total: 6m 51s	remaining: 1m 39s
# 805:	learn: 1286.2809275	total: 6m 52s	remaining: 1m 39s
# 806:	learn: 1285.9714159	total: 6m 52s	remaining: 1m 38s
# 807:	learn: 1285.6029631	total: 6m 53s	remaining: 1m 38s
# 808:	learn: 1285.4034561	total: 6m 53s	remaining: 1m 37s
# 809:	learn: 1285.2083044	total: 6m 54s	remaining: 1m 37s
# 810:	learn: 1285.0633763	total: 6m 55s	remaining: 1m 36s
# 811:	learn: 1284.9723824	total: 6m 55s	remaining: 1m 36s
# 812:	learn: 1284.7572169	total: 6m 56s	remaining: 1m 35s
# 813:	learn: 1284.3701786	total: 6m 56s	remaining: 1m 35s
# 814:	learn: 1284.3196840	total: 6m 57s	remaining: 1m 34s
# 815:	learn: 1284.0120631	total: 6m 57s	remaining: 1m 34s
# 816:	learn: 1283.7055482	total: 6m 58s	remaining: 1m 33s
# 817:	learn: 1283.6233491	total: 6m 58s	remaining: 1m 33s
# 818:	learn: 1283.4438669	total: 6m 59s	remaining: 1m 32s
# 819:	learn: 1283.3530895	total: 6m 59s	remaining: 1m 32s
# 820:	learn: 1283.2056429	total: 7m	remaining: 1m 31s
# 821:	learn: 1282.9532610	total: 7m	remaining: 1m 31s
# 822:	learn: 1282.7613738	total: 7m 1s	remaining: 1m 30s
# 823:	learn: 1282.6281448	total: 7m 2s	remaining: 1m 30s
# 824:	learn: 1282.4009966	total: 7m 2s	remaining: 1m 29s
# 825:	learn: 1282.3151442	total: 7m 2s	remaining: 1m 29s
# 826:	learn: 1282.1228436	total: 7m 3s	remaining: 1m 28s
# 827:	learn: 1281.9639842	total: 7m 3s	remaining: 1m 28s
# 828:	learn: 1281.8964397	total: 7m 4s	remaining: 1m 27s
# 829:	learn: 1281.7203662	total: 7m 5s	remaining: 1m 27s
# 830:	learn: 1281.6203827	total: 7m 5s	remaining: 1m 26s
# 831:	learn: 1281.1456692	total: 7m 6s	remaining: 1m 26s
# 832:	learn: 1280.8658065	total: 7m 6s	remaining: 1m 25s
# 833:	learn: 1280.6136845	total: 7m 7s	remaining: 1m 25s
# 834:	learn: 1280.4312648	total: 7m 7s	remaining: 1m 24s
# 835:	learn: 1280.3615950	total: 7m 8s	remaining: 1m 24s
# 836:	learn: 1279.9974430	total: 7m 8s	remaining: 1m 23s
# 837:	learn: 1279.8618235	total: 7m 9s	remaining: 1m 22s
# 838:	learn: 1279.6167713	total: 7m 9s	remaining: 1m 22s
# 839:	learn: 1279.3957420	total: 7m 10s	remaining: 1m 21s
# 840:	learn: 1279.1471487	total: 7m 10s	remaining: 1m 21s
# 841:	learn: 1278.8859449	total: 7m 11s	remaining: 1m 20s
# 842:	learn: 1278.6940445	total: 7m 11s	remaining: 1m 20s
# 843:	learn: 1278.5116613	total: 7m 12s	remaining: 1m 19s
# 844:	learn: 1278.3432438	total: 7m 12s	remaining: 1m 19s
# 845:	learn: 1277.9822608	total: 7m 13s	remaining: 1m 18s
# 846:	learn: 1277.6871853	total: 7m 13s	remaining: 1m 18s
# 847:	learn: 1277.5101653	total: 7m 14s	remaining: 1m 17s
# 848:	learn: 1277.3553955	total: 7m 14s	remaining: 1m 17s
# 849:	learn: 1277.1975300	total: 7m 15s	remaining: 1m 16s
# 850:	learn: 1277.0318043	total: 7m 16s	remaining: 1m 16s
# 851:	learn: 1276.9526379	total: 7m 16s	remaining: 1m 15s
# 852:	learn: 1276.7583194	total: 7m 17s	remaining: 1m 15s
# 853:	learn: 1276.6197412	total: 7m 17s	remaining: 1m 14s
# 854:	learn: 1276.4414312	total: 7m 18s	remaining: 1m 14s
# 855:	learn: 1276.1156198	total: 7m 18s	remaining: 1m 13s
# 856:	learn: 1275.9066074	total: 7m 19s	remaining: 1m 13s
# 857:	learn: 1275.6295132	total: 7m 19s	remaining: 1m 12s
# 858:	learn: 1275.3877574	total: 7m 20s	remaining: 1m 12s
# 859:	learn: 1275.2881453	total: 7m 20s	remaining: 1m 11s
# 860:	learn: 1275.1084196	total: 7m 21s	remaining: 1m 11s
# 861:	learn: 1274.7907084	total: 7m 21s	remaining: 1m 10s
# 862:	learn: 1274.7184457	total: 7m 22s	remaining: 1m 10s
# 863:	learn: 1274.5964538	total: 7m 22s	remaining: 1m 9s
# 864:	learn: 1274.5402620	total: 7m 23s	remaining: 1m 9s
# 865:	learn: 1274.1633952	total: 7m 23s	remaining: 1m 8s
# 866:	learn: 1273.9654399	total: 7m 24s	remaining: 1m 8s
# 867:	learn: 1273.7770507	total: 7m 24s	remaining: 1m 7s
# 868:	learn: 1273.5583258	total: 7m 25s	remaining: 1m 7s
# 869:	learn: 1273.4096878	total: 7m 26s	remaining: 1m 6s
# 870:	learn: 1273.1666191	total: 7m 26s	remaining: 1m 6s
# 871:	learn: 1272.9435987	total: 7m 27s	remaining: 1m 5s
# 872:	learn: 1272.7040453	total: 7m 27s	remaining: 1m 5s
# 873:	learn: 1272.5163071	total: 7m 28s	remaining: 1m 4s
# 874:	learn: 1272.2108123	total: 7m 28s	remaining: 1m 4s
# 875:	learn: 1272.0839814	total: 7m 29s	remaining: 1m 3s
# 876:	learn: 1271.9822797	total: 7m 29s	remaining: 1m 3s
# 877:	learn: 1271.7453675	total: 7m 30s	remaining: 1m 2s
# 878:	learn: 1271.7011996	total: 7m 30s	remaining: 1m 2s
# 879:	learn: 1271.4729523	total: 7m 31s	remaining: 1m 1s
# 880:	learn: 1271.3192868	total: 7m 31s	remaining: 1m 1s
# 881:	learn: 1270.9873142	total: 7m 32s	remaining: 1m
# 882:	learn: 1270.7719678	total: 7m 32s	remaining: 60s
# 883:	learn: 1270.6512137	total: 7m 33s	remaining: 59.5s
# 884:	learn: 1270.2352045	total: 7m 33s	remaining: 59s
# 885:	learn: 1270.1322943	total: 7m 34s	remaining: 58.4s
# 886:	learn: 1270.0688845	total: 7m 34s	remaining: 57.9s
# 887:	learn: 1269.9306969	total: 7m 35s	remaining: 57.4s
# 888:	learn: 1269.6482488	total: 7m 35s	remaining: 56.9s
# 889:	learn: 1269.4774712	total: 7m 36s	remaining: 56.4s
# 890:	learn: 1269.2591094	total: 7m 36s	remaining: 55.9s
# 891:	learn: 1269.1570326	total: 7m 37s	remaining: 55.4s
# 892:	learn: 1268.7611388	total: 7m 37s	remaining: 54.9s
# 893:	learn: 1268.7345900	total: 7m 38s	remaining: 54.4s
# 894:	learn: 1268.5699299	total: 7m 38s	remaining: 53.8s
# 895:	learn: 1268.2963971	total: 7m 39s	remaining: 53.3s
# 896:	learn: 1268.1829448	total: 7m 40s	remaining: 52.8s
# 897:	learn: 1268.1336602	total: 7m 40s	remaining: 52.3s
# 898:	learn: 1267.7988343	total: 7m 41s	remaining: 51.8s
# 899:	learn: 1267.6525729	total: 7m 41s	remaining: 51.3s
# 900:	learn: 1267.5661217	total: 7m 42s	remaining: 50.8s
# 901:	learn: 1267.2170267	total: 7m 42s	remaining: 50.3s
# 902:	learn: 1267.0182781	total: 7m 43s	remaining: 49.8s
# 903:	learn: 1266.7334650	total: 7m 43s	remaining: 49.3s
# 904:	learn: 1266.6705786	total: 7m 44s	remaining: 48.8s
# 905:	learn: 1266.5599301	total: 7m 45s	remaining: 48.2s
# 906:	learn: 1266.4567728	total: 7m 45s	remaining: 47.7s
# 907:	learn: 1266.2959910	total: 7m 46s	remaining: 47.2s
# 908:	learn: 1266.1344599	total: 7m 46s	remaining: 46.7s
# 909:	learn: 1265.8641027	total: 7m 47s	remaining: 46.2s
# 910:	learn: 1265.7585304	total: 7m 47s	remaining: 45.7s
# 911:	learn: 1265.3666281	total: 7m 48s	remaining: 45.2s
# 912:	learn: 1265.2318215	total: 7m 48s	remaining: 44.7s
# 913:	learn: 1265.1335986	total: 7m 49s	remaining: 44.2s
# 914:	learn: 1265.0414912	total: 7m 50s	remaining: 43.7s
# 915:	learn: 1264.7655258	total: 7m 50s	remaining: 43.2s
# 916:	learn: 1264.6548574	total: 7m 51s	remaining: 42.7s
# 917:	learn: 1264.6220698	total: 7m 51s	remaining: 42.1s
# 918:	learn: 1264.4915968	total: 7m 52s	remaining: 41.6s
# 919:	learn: 1264.3756275	total: 7m 52s	remaining: 41.1s
# 920:	learn: 1264.2887357	total: 7m 53s	remaining: 40.6s
# 921:	learn: 1264.2002736	total: 7m 53s	remaining: 40.1s
# 922:	learn: 1264.0860518	total: 7m 54s	remaining: 39.6s
# 923:	learn: 1263.8279321	total: 7m 55s	remaining: 39.1s
# 924:	learn: 1263.7588458	total: 7m 55s	remaining: 38.6s
# 925:	learn: 1263.6820783	total: 7m 56s	remaining: 38.1s
# 926:	learn: 1263.2208998	total: 7m 56s	remaining: 37.5s
# 927:	learn: 1263.0417600	total: 7m 57s	remaining: 37s
# 928:	learn: 1262.8306131	total: 7m 57s	remaining: 36.5s
# 929:	learn: 1262.7173790	total: 7m 58s	remaining: 36s
# 930:	learn: 1262.5574284	total: 7m 58s	remaining: 35.5s
# 931:	learn: 1262.4862474	total: 7m 59s	remaining: 35s
# 932:	learn: 1262.3557277	total: 7m 59s	remaining: 34.5s
# 933:	learn: 1261.8439403	total: 8m	remaining: 34s
# 934:	learn: 1261.7674766	total: 8m 1s	remaining: 33.4s
# 935:	learn: 1261.4171597	total: 8m 1s	remaining: 32.9s
# 936:	learn: 1261.3431466	total: 8m 2s	remaining: 32.4s
# 937:	learn: 1261.2488724	total: 8m 2s	remaining: 31.9s
# 938:	learn: 1261.1286057	total: 8m 3s	remaining: 31.4s
# 939:	learn: 1260.9858503	total: 8m 3s	remaining: 30.9s
# 940:	learn: 1260.8594022	total: 8m 4s	remaining: 30.4s
# 941:	learn: 1260.5792766	total: 8m 4s	remaining: 29.9s
# 942:	learn: 1260.4081212	total: 8m 5s	remaining: 29.3s
# 943:	learn: 1260.3383048	total: 8m 5s	remaining: 28.8s
# 944:	learn: 1260.1607603	total: 8m 6s	remaining: 28.3s
# 945:	learn: 1260.1012747	total: 8m 7s	remaining: 27.8s
# 946:	learn: 1259.8249263	total: 8m 7s	remaining: 27.3s
# 947:	learn: 1259.5011634	total: 8m 8s	remaining: 26.8s
# 948:	learn: 1259.1197516	total: 8m 8s	remaining: 26.3s
# 949:	learn: 1258.8836313	total: 8m 9s	remaining: 25.7s
# 950:	learn: 1258.6598048	total: 8m 9s	remaining: 25.2s
# 951:	learn: 1258.5873127	total: 8m 10s	remaining: 24.7s
# 952:	learn: 1258.5237440	total: 8m 10s	remaining: 24.2s
# 953:	learn: 1258.4524012	total: 8m 11s	remaining: 23.7s
# 954:	learn: 1258.3775448	total: 8m 11s	remaining: 23.2s
# 955:	learn: 1258.2490004	total: 8m 12s	remaining: 22.7s
# 956:	learn: 1257.9709140	total: 8m 13s	remaining: 22.2s
# 957:	learn: 1257.8614501	total: 8m 13s	remaining: 21.6s
# 958:	learn: 1257.7380126	total: 8m 14s	remaining: 21.1s
# 959:	learn: 1257.6118978	total: 8m 14s	remaining: 20.6s
# 960:	learn: 1257.3059217	total: 8m 15s	remaining: 20.1s
# 961:	learn: 1257.1324919	total: 8m 15s	remaining: 19.6s
# 962:	learn: 1256.8695399	total: 8m 16s	remaining: 19.1s
# 963:	learn: 1256.6092919	total: 8m 16s	remaining: 18.6s
# 964:	learn: 1256.4658636	total: 8m 17s	remaining: 18s
# 965:	learn: 1256.3464828	total: 8m 17s	remaining: 17.5s
# 966:	learn: 1256.2069211	total: 8m 18s	remaining: 17s
# 967:	learn: 1256.0975699	total: 8m 18s	remaining: 16.5s
# 968:	learn: 1256.0414431	total: 8m 19s	remaining: 16s
# 969:	learn: 1255.8557107	total: 8m 20s	remaining: 15.5s
# 970:	learn: 1255.7689343	total: 8m 20s	remaining: 14.9s
# 971:	learn: 1255.7049572	total: 8m 21s	remaining: 14.4s
# 972:	learn: 1255.2940905	total: 8m 21s	remaining: 13.9s
# 973:	learn: 1255.0595122	total: 8m 22s	remaining: 13.4s
# 974:	learn: 1254.5587968	total: 8m 22s	remaining: 12.9s
# 975:	learn: 1254.4332556	total: 8m 23s	remaining: 12.4s
# 976:	learn: 1254.3557965	total: 8m 23s	remaining: 11.9s
# 977:	learn: 1254.3236275	total: 8m 24s	remaining: 11.3s
# 978:	learn: 1254.0729944	total: 8m 24s	remaining: 10.8s
# 979:	learn: 1253.8883331	total: 8m 25s	remaining: 10.3s
# 980:	learn: 1253.7972746	total: 8m 25s	remaining: 9.79s
# 981:	learn: 1253.6393203	total: 8m 26s	remaining: 9.28s
# 982:	learn: 1253.4494129	total: 8m 26s	remaining: 8.76s
# 983:	learn: 1253.0458718	total: 8m 27s	remaining: 8.25s
# 984:	learn: 1252.8959052	total: 8m 27s	remaining: 7.73s
# 985:	learn: 1252.7521901	total: 8m 28s	remaining: 7.22s
# 986:	learn: 1252.5770895	total: 8m 28s	remaining: 6.7s
# 987:	learn: 1252.2627896	total: 8m 29s	remaining: 6.19s
# 988:	learn: 1252.0582755	total: 8m 30s	remaining: 5.67s
# 989:	learn: 1251.9496116	total: 8m 30s	remaining: 5.16s
# 990:	learn: 1251.8588285	total: 8m 31s	remaining: 4.64s
# 991:	learn: 1251.7308567	total: 8m 31s	remaining: 4.13s
# 992:	learn: 1251.6015166	total: 8m 32s	remaining: 3.61s
# 993:	learn: 1251.4602784	total: 8m 32s	remaining: 3.1s
# 994:	learn: 1251.1531482	total: 8m 33s	remaining: 2.58s
# 995:	learn: 1250.9489462	total: 8m 33s	remaining: 2.06s
# 996:	learn: 1250.7925409	total: 8m 34s	remaining: 1.55s
# 997:	learn: 1250.3025667	total: 8m 35s	remaining: 1.03s
# 998:	learn: 1250.1166700	total: 8m 35s	remaining: 516ms
# 999:	learn: 1249.7836903	total: 8m 36s	remaining: 0us
# CPU times: user 8min 35s, sys: 881 ms, total: 8min 35s
# Wall time: 8min 39s
# RMSE: 1542.5782554272123

# %%
# Implementacion con LightGBM

# Crear un conjunto de lgbm de entrenamiento
features_train['brand'] = features_train['brand'].astype('category').cat.codes
features_train['model'] = features_train['model'].astype('category').cat.codes

train_data = lgb.Dataset(features_train, label=target_train)

# Crear un conjunto de lgbm de prueba
features_test['brand'] = features_test['brand'].astype('category').cat.codes
features_test['model'] = features_test['model'].astype('category').cat.codes



# Definir los parámetros del modelo
# Es un modelo de regresión, se evaluara con la raíz del error cuadrático medio
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'boosting_type': 'gbdt',
    'num_leaves': 41,
    'learning_rate': 0.1,
    'feature_fraction': 0.9
}

# Entrenar el modelo
num_round = 1000
# %time bst = lgb.train(params, train_data, num_round)

# Realiza predicciones en el conjunto de prueba
predicts = bst.predict(features_test, num_iteration=bst.best_iteration)

# Evaluar con RMSE
rmse = mean_squared_error(target_test, predicts) ** 0.5
print(f'RMSE: {rmse}')
# Out:
# /tmp/ipykernel_91/3649278590.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_train['brand'] = features_train['brand'].astype('category').cat.codes
# /tmp/ipykernel_91/3649278590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_train['model'] = features_train['model'].astype('category').cat.codes
# /tmp/ipykernel_91/3649278590.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_test['brand'] = features_test['brand'].astype('category').cat.codes
# /tmp/ipykernel_91/3649278590.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_test['model'] = features_test['model'].astype('category').cat.codes
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004627 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 899
# [LightGBM] [Info] Number of data points in the train set: 147571, number of used features: 10
# [LightGBM] [Info] Start training from score 5354.426195
# CPU times: user 16.6 s, sys: 126 ms, total: 16.8 s
# Wall time: 16.9 s
# RMSE: 1624.2413826017148

# %% [markdown]
# **Nota:** Hubo una mejora significativa en tiempo comparación de la regresión lineal, quedando a la par con el bosque aleatorio basico. Sin embargo la mejora real consiste en el RMSE que es comparable con Catboost pero mucho mas rápido. Probablemente el mejor modelo hasta ahora.

# %% [markdown]
# ### <a id='toc1_4_4_'></a>[XGBoost](#toc0_)

# %%
# Implementacion con XGBoost
# Crear una matriz DMatrix para XGBoost
dtrain = xgb.DMatrix(features_train_scaled_ohe, label=target_train)
dtest = xgb.DMatrix(features_test_scaled_ohe, label=target_test)

# Definir los parámetros del modelo
# Regresión y se evalua con la raíz del error cuadrático medio
params = {
    'objective': 'reg:squarederror',  
    'eval_metric': 'rmse',
    'max_depth': 34,
    'learning_rate': 0.1,
    'subsample': 0.8
}

# Entrenar el modelo
num_round = 1
# %time bst = xgb.train(params, dtrain, num_round)

# Realizar predicciones en el conjunto de prueba
predicts = bst.predict(dtest)

# Evalúa el rendimiento del modelo con RMSE
rmse = mean_squared_error(target_test, predicts) ** 0.5
print(f'RMSE: {rmse}')
# Out:
# CPU times: user 30.5 s, sys: 260 ms, total: 30.8 s
# Wall time: 30.9 s
# RMSE: 6932.95591701738

# %% [markdown]
# **Nota:**
# Para este modelo se necesita one hot encoding. Quiza por eso es mucho mas lento que los otros. Por esta razon los hiperparametros no se cambiaron mucho.
#
# Se hizo una prueba en visual studio con num_round = 100. Y los resultados en tiempo fueron 481 s de entrenamiento y 4845.69 RMSE. Este modelo tuvo peor desempeño que la prueba de cordura. Los hiperparametros podrian mejorarse pero el tiempo de entrenamiento es muy largo.

# %% [markdown]
# ## <a id='toc1_5_'></a>[Análisis del modelo](#toc0_)

# %% [markdown]
# La siguiente tabla muestra la comparación del tiempo de entrenamiento y una calidad que se obtuvo a partir de la raíz del error cuadrático medio (RMSE) de distintos modelos con los mejores hiperprámetros. La prueba de cordura se definio con el modelo del regresión lineal. Se destaca el modelo LightGBM que obtuvo un tiempo de entrenamiento relativamente bajo y obtuvo el segundo mejor puedo en calidad. Sin embargo Catboost obtuvo un error menor, el timpo fue de 9 mins aproxidamente, creo que es un tiempo tolerable de entrenamiento.
#
# |          Modelo          | Wall Time de entrenamiento | Calidad (RMSE) | Diferencia en tiempo | Diferencia en calidad |
# |--------------------------|----------------------------|----------------|----------------------|-----------------------|
# | Regresión Lineal         |            35.4s           |     4753.70    |        N/A           |         N/A           |
# | Bosque aleatorio (basico)|            21.5s           |     4730.94    |      -39.22%         |        -0.10%         |
# |        Catboost          |           522.0s           |     1542.58    |    +1378.53%         |       -67.59%         |
# |        LightGBM          |            20.1s           |     1624.24    |      -43.22%         |       -66.00%         |
# |        XGBoost           |           481.0s           |     4845.69    |    +1257.63%         |       +1.94%          |
